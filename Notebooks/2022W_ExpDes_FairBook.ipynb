# %% [markdown]
# This notebook should be run on Google Colab

# %%
# import
import os
import random as rd
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# set plot style: grey grid in the background:
sns.set(style="darkgrid")

from sklearn.preprocessing import MinMaxScaler
from collections import defaultdict
from scipy import stats
from numpy.linalg import norm
import time
from tqdm import tqdm

# %%
import tensorflow as tf

# %%
tf.set_random_seed(120)

# %% [markdown]
# ## Settings

# %%
# constants and initialization
item_threshold = 1 # 1 means no filtering
my_seed = 0
rd.seed(my_seed)
np.random.seed(my_seed)
predict_col = 'bid'
top_fraction = 0.2
feedback_column = 'rating'
user_events_file = "https://raw.githubusercontent.com/rahmanidashti/FairBook/main/dataset/Bookcrossing/BX-Book-Explicit-5Rate-Map.csv"
high_user_file = "https://raw.githubusercontent.com/rahmanidashti/FairBook/main/dataset/Bookcrossing/user-groups/active_users.txt"
low_user_file = "https://raw.githubusercontent.com/rahmanidashti/FairBook/main/dataset/Bookcrossing/user-groups/inactive_users.txt"
medium_user_file = "https://raw.githubusercontent.com/rahmanidashti/FairBook/main/dataset/Bookcrossing/user-groups/medium_users.txt"

# %% [markdown]
# ## Load Dataset

# %%
# read user events
df_events = pd.read_csv(user_events_file, sep=',')
print('No. of user interactions: ' + str(len(df_events)))
# Out:
# No. of user interactions: 88552

# %%
df_events.head()
# Out:
#    uid  bid  rating
# 0    0    0       8
# 1    0    1      10
# 2    0    2      10
# 3    0    3      10
# 4    0    4      10

# %%
df_events.iat[0,2]
# Out:
# 8

# %%
df_events = df_events[df_events[feedback_column] >= item_threshold]
print('No. filtered user interactions: ' + str(len(df_events)))
print('No. filtered items: ' + str(len(df_events[predict_col].unique())))
# Out:
# No. filtered user interactions: 88552
# No. filtered items: 6921

# %% [markdown]
# ## User-Item Analysis

# %%
# get user distribution
user_dist = df_events['uid'].value_counts()
num_users = len(user_dist)
print('No. users: ' + str(num_users))
print('Mean books per user: ' + str(user_dist.mean()))
print('Min books per user: ' + str(user_dist.min()))
print('Max books per user: ' + str(user_dist.max()))
# Out:
# No. users: 6358
# Mean books per user: 13.927650204466813
# Min books per user: 5
# Max books per user: 153

# %%
# get item distribution
item_dist = df_events['bid'].value_counts()
num_items = len(item_dist)
print('No. items: ' + str(num_items))
# Out:
# No. items: 6921

# %%
# plot item distribution
plt.figure()
plt.plot(item_dist.values)
plt.xlabel('Book (log)', fontsize='14')
plt.xticks(fontsize='13')
plt.yticks(fontsize='13')
plt.ylabel('Number of readers (log)', fontsize='15')
plt.xscale('log')
plt.yscale('log')
plt.savefig('book_long_tail_log.pdf', dpi=300, bbox_inches='tight')

# %%
# plot item distribution
plt.figure()
plt.plot(item_dist.values)
plt.xlabel('Book', fontsize='14')
plt.xticks(fontsize='10')
plt.yticks(fontsize='13')
plt.ylabel('Number of readers', fontsize='15')
plt.savefig('book_long_tail_normal.pdf', dpi=300, bbox_inches='tight')

# %%
# get top items
num_top = int(top_fraction * num_items)
top_item_dist = item_dist[:num_top]
print('No. top items: ' + str(len(top_item_dist)))
# Out:
# No. top items: 1384

# %% [markdown]
# ## User Groups Analysis

# %%
# read users
low_users = pd.read_csv(low_user_file, sep=',').set_index('user_id')
medium_users = pd.read_csv(medium_user_file, sep=',').set_index('user_id')
high_users = pd.read_csv(high_user_file, sep=',').set_index('user_id')

no_users = len(low_users) + len(medium_users) + len(high_users)

print('No. of users: ' + str(no_users))
print('No. of inactive users: ' + str(len(low_users)))
print('No. of medium users: ' + str(len(medium_users)))
print('No. of active users: ' + str(len(high_users)))
# Out:
# No. of users: 6358
# No. of inactive users: 1271
# No. of medium users: 3816
# No. of active users: 1271

# %%
# get pop fractions
predict_col = 'bid'

pop_count = [] # number of top items per user
user_hist = [] # user history sizes
pop_fraq = [] # relative number of top items per user
pop_item_fraq = [] # average popularity of items in user profiles

low_profile_size = 0
low_gap = 0
medium_profile_size = 0
medium_gap = 0
high_profile_size = 0
high_gap = 0

low_count = 0
med_count = 0
high_count = 0

for u, df in df_events.groupby('uid'):
    no_user_items = len(set(df[predict_col])) # profile size
    no_user_pop_items = len(set(df[predict_col]) & set(top_item_dist.index)) # top items in profile
    pop_count.append(no_user_pop_items)
    user_hist.append(no_user_items)
    pop_fraq.append(no_user_pop_items / no_user_items)
    # get popularity (= fraction of users interacted with item) of user items and calculate average of it
    user_pop_item_fraq = sum(item_dist[df[predict_col]] / no_users) / no_user_items
    pop_item_fraq.append(user_pop_item_fraq)
    if u in low_users.index: # get user group-specific values
        low_profile_size += no_user_items
        low_gap += user_pop_item_fraq
        low_count += 1
    elif u in medium_users.index:
        medium_profile_size += no_user_items
        medium_gap += user_pop_item_fraq
        med_count += 1
    else:
        high_profile_size += no_user_items
        high_gap += user_pop_item_fraq
        high_count += 1

low_profile_size /= len(low_users)
medium_profile_size /= len(medium_users)
high_profile_size /= len(high_users)

low_gap /= len(low_users)
medium_gap /= len(medium_users)
high_gap /= len(high_users)

print('Low count (for check): ' + str(low_count))
print('Med count (for check): ' + str(med_count))
print('High count (for check): ' + str(high_count))
# Out:
# Low count (for check): 1271
# Med count (for check): 3816
# High count (for check): 1271

# %%
plt.figure()
plt.plot(sorted(pop_fraq))
plt.xlabel('User', fontsize='15')
plt.xticks(fontsize='13')
plt.ylabel('Ratio of popular books', fontsize='15')
plt.yticks(fontsize='13')
plt.axhline(y=0.8, color='black', linestyle='--', label='80% ratio of popular books')
plt.legend(fontsize='15')
plt.savefig('user_book_ratio.pdf', dpi=300, bbox_inches='tight')

# %%
plt.figure()
slope, intercept, r_value, p_value, std_err = stats.linregress(user_hist, pop_count)
print('R-value: ' + str(r_value))
line = slope * np.array(user_hist) + intercept
plt.plot(user_hist, pop_count, 'o', user_hist, line)
plt.xlabel('User profile size', fontsize='15')
plt.xticks(fontsize='13')
plt.ylabel('Number of popular books', fontsize='15')
plt.yticks(fontsize='13')
plt.savefig('corr_user_pop.pdf', dpi=300, bbox_inches='tight')
# Out:
# R-value: 0.9230435903359937

# %%
# we can remore it and do not use it
plt.figure()
slope, intercept, r_value, p_value, std_err = stats.linregress(user_hist, pop_fraq)
line = slope * np.array(user_hist) + intercept
plt.plot(user_hist, pop_fraq, 'o', user_hist, line)
plt.xlabel('User profile size')
plt.ylabel('Percentage of popular books')
plt.savefig('corr_user_ratio.pdf', dpi=300, bbox_inches='tight')

# %%
plt.figure()
slope, intercept, r_value, p_value, std_err = stats.linregress(user_hist, pop_item_fraq)
print('R-value: ' + str(r_value))
print(stats.spearmanr(user_hist, pop_item_fraq))
line = slope * np.array(user_hist) + intercept
plt.plot(user_hist, pop_item_fraq, 'o', user_hist, line)
plt.xlabel('User profile size', fontsize='15')
plt.ylabel('Average popularity of books', fontsize='15')
plt.xticks(fontsize='13')
plt.yticks(fontsize='13')
plt.savefig('corr_user_avg.pdf', dpi=300, bbox_inches='tight')
# Out:
# R-value: -0.03357522222625168
# SpearmanrResult(correlation=0.06291508367304682, pvalue=5.149636716688308e-07)

# %%
sns.set(rc = {'figure.figsize':(5,4)})

# set plot style: grey grid in the background:
sns.set(style="darkgrid")
plt.figure()
plt.bar(0, low_profile_size)
plt.bar(1, medium_profile_size)
plt.bar(2, high_profile_size)
plt.xticks(np.arange(3), ['Niche', 'Diverse', 'BestSeller'])
plt.xlabel('User groups')
plt.ylabel('Average user profile size')
plt.savefig('group_size.pdf', dpi=300, bbox_inches='tight')

# %%
print('Average LowMS profile size: ' + str(low_profile_size))
print('Average MedMS profile size: ' + str(medium_profile_size))
print('Average HighMS profile size: ' + str(high_profile_size))
# Out:
# Average LowMS profile size: 11.019669551534225
# Average MedMS profile size: 16.21829140461216
# Average HighMS profile size: 9.958300550747444

# %% [markdown]
# ## Recommendation using Cornac

# %%
# install cornac framework for RecSys
! pip install cornac
# Out:
# Requirement already satisfied: cornac in h:\anaconda\envs\tf15\lib\site-packages (1.14.2)
# Requirement already satisfied: tqdm>=4.19 in h:\anaconda\envs\tf15\lib\site-packages (from cornac) (4.64.1)
# Requirement already satisfied: scipy in h:\anaconda\envs\tf15\lib\site-packages (from cornac) (1.7.3)
# Requirement already satisfied: powerlaw in h:\anaconda\envs\tf15\lib\site-packages (from cornac) (1.5)
# Requirement already satisfied: numpy in h:\anaconda\envs\tf15\lib\site-packages (from cornac) (1.21.5)
# Requirement already satisfied: colorama in h:\anaconda\envs\tf15\lib\site-packages (from tqdm>=4.19->cornac) (0.4.6)
# Requirement already satisfied: matplotlib in h:\anaconda\envs\tf15\lib\site-packages (from powerlaw->cornac) (3.5.3)
# Requirement already satisfied: mpmath in h:\anaconda\envs\tf15\lib\site-packages (from powerlaw->cornac) (1.2.1)
# Requirement already satisfied: packaging>=20.0 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in h:\anaconda\envs\tf15\lib\site-packages (from matplotlib->powerlaw->cornac) (0.11.0)
# Requirement already satisfied: typing-extensions in h:\anaconda\envs\tf15\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->powerlaw->cornac) (4.4.0)
# Requirement already satisfied: six>=1.5 in h:\anaconda\envs\tf15\lib\site-packages (from python-dateutil>=2.7->matplotlib->powerlaw->cornac) (1.16.0)

# %% [markdown]
# ### Switch to Tensorflow 1

# %%
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
#python -m pip install --upgrade pip

# %%
# Out:
# ^C

# %%
tf.__version__
# Out:
# '1.15.0'

# %% [markdown]
# ### Import Cornac Reqired Packages

# %%
import cornac
from cornac.eval_methods import RatioSplit
from cornac.data import Reader
from cornac.models import MostPop, MF, PMF, BPR, NeuMF, WMF, HPF, VAECF, NMF
from cornac.metrics import MAE, MSE, RMSE, Precision, Recall, NDCG, AUC, MAP, FMeasure, MRR
# Out:
# FM model is only supported on Linux.
# Windows executable can be found at http://www.libfm.org.

# %%
# load txt file to feed into Cornac
os.system("wget https://raw.githubusercontent.com/rahmanidashti/FairBook/main/dataset/Bookcrossing/BX-Book-Explicit-5Rate-Map.txt")
# Out:
# 1

# %%
# load dataset in Cornac
reader = Reader()
data = reader.read('BX-Book-Explicit-5Rate-Map.txt', fmt='UIR', sep=',')

# %%
data
# Out:
# [('0', '0', 8.0),
#  ('0', '1', 10.0),
#  ('0', '2', 10.0),
#  ('0', '3', 10.0),
#  ('0', '4', 10.0),
#  ('1', '5', 10.0),
#  ('1', '6', 9.0),
#  ('1', '7', 8.0),
#  ('1', '8', 10.0),
#  ('1', '9', 8.0),
#  ('1', '10', 7.0),
#  ('1', '11', 8.0),
#  ('1', '12', 8.0),
#  ('1', '13', 9.0),
#  ('1', '14', 10.0),
#  ('2', '15', 8.0),
#  ('2', '16', 7.0),
#  ('2', '17', 8.0),
#  ('2', '18', 9.0),
#  ('2', '19', 8.0),
#  ('2', '20', 2.0),
#  ('3', '21', 5.0),
#  ('3', '22', 5.0),
#  ('3', '23', 6.0),
#  ('3', '24', 7.0),
#  ('3', '25', 7.0),
#  ('3', '26', 7.0),
#  ('3', '27', 6.0),
#  ('3', '28', 8.0),
#  ('3', '29', 7.0),
#  ('3', '30', 5.0),
#  ('3', '31', 7.0),
#  ('3', '32', 6.0),
#  ('3', '33', 7.0),
#  ('3', '34', 7.0),
#  ('4', '35', 10.0),
#  ('4', '36', 10.0),
#  ('4', '37', 10.0),
#  ('4', '38', 10.0),
#  ('4', '39', 10.0),
#  ('4', '40', 10.0),
#  ('4', '41', 10.0),
#  ('4', '42', 10.0),
#  ('4', '43', 10.0),
#  ('5', '44', 9.0),
#  ('5', '45', 9.0),
#  ('5', '46', 9.0),
#  ('5', '47', 8.0),
#  ('5', '48', 8.0),
#  ('5', '49', 8.0),
#  ('6', '50', 7.0),
#  ('6', '51', 4.0),
#  ('6', '52', 7.0),
#  ('6', '53', 6.0),
#  ('6', '54', 5.0),
#  ('6', '55', 5.0),
#  ('6', '56', 4.0),
#  ('7', '57', 10.0),
#  ('7', '58', 7.0),
#  ('7', '59', 9.0),
#  ('7', '60', 10.0),
#  ('7', '61', 8.0),
#  ('7', '62', 8.0),
#  ('7', '63', 10.0),
#  ('7', '64', 9.0),
#  ('7', '65', 8.0),
#  ('7', '66', 9.0),
#  ('7', '67', 9.0),
#  ('7', '68', 9.0),
#  ('7', '69', 9.0),
#  ('7', '70', 8.0),
#  ('7', '71', 8.0),
#  ('7', '72', 9.0),
#  ('7', '73', 9.0),
#  ('7', '74', 8.0),
#  ('7', '75', 9.0),
#  ('7', '76', 7.0),
#  ('7', '77', 7.0),
#  ('7', '78', 8.0),
#  ('7', '79', 9.0),
#  ('7', '80', 8.0),
#  ('7', '81', 10.0),
#  ('7', '82', 9.0),
#  ('7', '83', 10.0),
#  ('7', '84', 10.0),
#  ('7', '85', 8.0),
#  ('7', '86', 10.0),
#  ('7', '87', 6.0),
#  ('7', '88', 8.0),
#  ('7', '89', 8.0),
#  ('7', '90', 9.0),
#  ('7', '91', 10.0),
#  ('7', '92', 10.0),
#  ('7', '93', 9.0),
#  ('7', '94', 9.0),
#  ('7', '95', 8.0),
#  ('7', '96', 8.0),
#  ('7', '97', 10.0),
#  ('7', '98', 9.0),
#  ('7', '99', 5.0),
#  ('7', '100', 8.0),
#  ('7', '101', 9.0),
#  ('7', '102', 8.0),
#  ('7', '103', 9.0),
#  ('7', '104', 9.0),
#  ('7', '105', 9.0),
#  ('7', '106', 8.0),
#  ('7', '107', 10.0),
#  ('7', '108', 10.0),
#  ('7', '109', 10.0),
#  ('7', '110', 10.0),
#  ('7', '111', 10.0),
#  ('7', '112', 10.0),
#  ('7', '113', 10.0),
#  ('7', '114', 10.0),
#  ('7', '115', 10.0),
#  ('7', '116', 8.0),
#  ('7', '117', 10.0),
#  ('7', '118', 7.0),
#  ('7', '119', 10.0),
#  ('7', '120', 10.0),
#  ('7', '121', 10.0),
#  ('7', '122', 10.0),
#  ('7', '123', 7.0),
#  ('8', '124', 7.0),
#  ('8', '125', 5.0),
#  ('8', '24', 5.0),
#  ('8', '126', 7.0),
#  ('8', '127', 7.0),
#  ('9', '128', 7.0),
#  ('9', '129', 7.0),
#  ('9', '130', 7.0),
#  ('9', '131', 8.0),
#  ('9', '132', 10.0),
#  ('9', '133', 8.0),
#  ('10', '134', 10.0),
#  ('10', '135', 10.0),
#  ('10', '136', 10.0),
#  ('10', '137', 10.0),
#  ('10', '138', 10.0),
#  ('10', '139', 10.0),
#  ('10', '140', 10.0),
#  ('10', '141', 10.0),
#  ('10', '142', 10.0),
#  ('10', '143', 10.0),
#  ('10', '144', 10.0),
#  ('10', '145', 10.0),
#  ('10', '146', 10.0),
#  ('10', '147', 10.0),
#  ('10', '148', 10.0),
#  ('10', '149', 10.0),
#  ('10', '150', 10.0),
#  ('10', '151', 10.0),
#  ('10', '152', 10.0),
#  ('11', '57', 5.0),
#  ('11', '153', 9.0),
#  ('11', '154', 9.0),
#  ('11', '155', 4.0),
#  ('11', '156', 8.0),
#  ('11', '157', 8.0),
#  ('12', '158', 8.0),
#  ('12', '159', 8.0),
#  ('12', '74', 6.0),
#  ('12', '160', 8.0),
#  ('12', '161', 7.0),
#  ('12', '162', 8.0),
#  ('12', '163', 7.0),
#  ('13', '164', 8.0),
#  ('13', '165', 6.0),
#  ('13', '166', 7.0),
#  ('13', '167', 8.0),
#  ('13', '168', 5.0),
#  ('13', '169', 8.0),
#  ('13', '170', 9.0),
#  ('13', '171', 8.0),
#  ('13', '172', 8.0),
#  ('13', '173', 8.0),
#  ('13', '174', 7.0),
#  ('13', '175', 8.0),
#  ('14', '176', 4.0),
#  ('14', '177', 9.0),
#  ('14', '178', 5.0),
#  ('14', '146', 6.0),
#  ('14', '179', 10.0),
#  ('14', '180', 6.0),
#  ('15', '181', 8.0),
#  ('15', '182', 7.0),
#  ('15', '183', 3.0),
#  ('15', '184', 8.0),
#  ('15', '185', 5.0),
#  ('15', '186', 9.0),
#  ('15', '187', 10.0),
#  ('15', '188', 8.0),
#  ('16', '189', 10.0),
#  ('16', '190', 5.0),
#  ('16', '191', 6.0),
#  ('16', '192', 10.0),
#  ('16', '193', 7.0),
#  ('17', '194', 7.0),
#  ('17', '195', 6.0),
#  ('17', '196', 7.0),
#  ('17', '197', 9.0),
#  ('17', '198', 10.0),
#  ('18', '199', 9.0),
#  ('18', '200', 8.0),
#  ('18', '201', 10.0),
#  ('18', '202', 10.0),
#  ('18', '203', 8.0),
#  ('18', '204', 10.0),
#  ('18', '205', 9.0),
#  ('18', '206', 9.0),
#  ('19', '207', 9.0),
#  ('19', '208', 7.0),
#  ('19', '209', 6.0),
#  ('19', '210', 7.0),
#  ('19', '211', 6.0),
#  ('19', '212', 6.0),
#  ('19', '213', 6.0),
#  ('19', '214', 7.0),
#  ('20', '215', 6.0),
#  ('20', '216', 6.0),
#  ('20', '217', 7.0),
#  ('20', '218', 8.0),
#  ('20', '219', 7.0),
#  ('20', '220', 7.0),
#  ('20', '221', 7.0),
#  ('20', '222', 7.0),
#  ('20', '223', 7.0),
#  ('20', '224', 7.0),
#  ('20', '225', 7.0),
#  ('20', '226', 8.0),
#  ('21', '227', 8.0),
#  ('21', '228', 6.0),
#  ('21', '229', 7.0),
#  ('21', '230', 8.0),
#  ('21', '231', 10.0),
#  ('21', '232', 6.0),
#  ('22', '233', 5.0),
#  ('22', '234', 10.0),
#  ('22', '235', 10.0),
#  ('22', '236', 8.0),
#  ('22', '237', 7.0),
#  ('22', '238', 8.0),
#  ('22', '239', 9.0),
#  ('22', '192', 9.0),
#  ('22', '240', 10.0),
#  ('22', '108', 9.0),
#  ('22', '241', 7.0),
#  ('22', '242', 10.0),
#  ('23', '243', 6.0),
#  ('23', '244', 8.0),
#  ('23', '245', 8.0),
#  ('23', '246', 6.0),
#  ('23', '247', 7.0),
#  ('23', '248', 5.0),
#  ('24', '59', 8.0),
#  ('24', '249', 8.0),
#  ('24', '250', 8.0),
#  ('24', '251', 8.0),
#  ('24', '252', 8.0),
#  ('24', '165', 5.0),
#  ('24', '253', 8.0),
#  ('24', '254', 9.0),
#  ('24', '255', 8.0),
#  ('24', '256', 8.0),
#  ('24', '257', 8.0),
#  ('24', '258', 6.0),
#  ('24', '259', 5.0),
#  ('24', '260', 3.0),
#  ('24', '261', 8.0),
#  ('24', '262', 8.0),
#  ('24', '263', 8.0),
#  ('24', '264', 5.0),
#  ('24', '265', 8.0),
#  ('24', '266', 6.0),
#  ('24', '267', 8.0),
#  ('24', '268', 8.0),
#  ('24', '151', 7.0),
#  ('24', '269', 5.0),
#  ('24', '270', 7.0),
#  ('24', '271', 6.0),
#  ('25', '272', 7.0),
#  ('25', '273', 9.0),
#  ('25', '274', 7.0),
#  ('25', '275', 8.0),
#  ('25', '276', 8.0),
#  ('25', '277', 8.0),
#  ('25', '278', 8.0),
#  ('25', '279', 7.0),
#  ('25', '280', 8.0),
#  ('25', '281', 9.0),
#  ('25', '282', 4.0),
#  ('25', '283', 8.0),
#  ('25', '284', 9.0),
#  ('25', '285', 8.0),
#  ('25', '152', 9.0),
#  ('25', '286', 8.0),
#  ('26', '287', 8.0),
#  ('26', '288', 7.0),
#  ('26', '289', 6.0),
#  ('26', '290', 7.0),
#  ('26', '291', 4.0),
#  ('26', '292', 8.0),
#  ('26', '293', 9.0),
#  ('26', '195', 9.0),
#  ('26', '294', 9.0),
#  ('26', '295', 8.0),
#  ('26', '296', 7.0),
#  ('26', '297', 6.0),
#  ('26', '298', 8.0),
#  ('26', '299', 7.0),
#  ('27', '300', 10.0),
#  ('27', '301', 8.0),
#  ('27', '302', 7.0),
#  ('27', '303', 5.0),
#  ('27', '304', 7.0),
#  ('27', '305', 9.0),
#  ('27', '306', 5.0),
#  ('27', '307', 7.0),
#  ('27', '308', 4.0),
#  ('27', '309', 9.0),
#  ('27', '144', 7.0),
#  ('27', '310', 5.0),
#  ('27', '87', 8.0),
#  ('27', '311', 4.0),
#  ('27', '266', 6.0),
#  ('27', '312', 8.0),
#  ('27', '313', 9.0),
#  ('27', '314', 6.0),
#  ('28', '315', 3.0),
#  ('28', '316', 2.0),
#  ('28', '317', 4.0),
#  ('28', '318', 9.0),
#  ('28', '319', 3.0),
#  ('28', '320', 3.0),
#  ('28', '321', 3.0),
#  ('28', '322', 1.0),
#  ('28', '323', 8.0),
#  ('28', '324', 10.0),
#  ('28', '325', 7.0),
#  ('28', '326', 8.0),
#  ('29', '327', 7.0),
#  ('29', '328', 7.0),
#  ('29', '329', 9.0),
#  ('29', '330', 8.0),
#  ('29', '331', 8.0),
#  ('29', '285', 9.0),
#  ('29', '332', 8.0),
#  ('30', '333', 9.0),
#  ('30', '334', 8.0),
#  ('30', '335', 7.0),
#  ('30', '336', 8.0),
#  ('30', '337', 9.0),
#  ('30', '338', 8.0),
#  ('30', '339', 10.0),
#  ('30', '340', 10.0),
#  ('30', '341', 10.0),
#  ('30', '342', 8.0),
#  ('31', '343', 8.0),
#  ('31', '344', 7.0),
#  ('31', '345', 7.0),
#  ('31', '346', 7.0),
#  ('31', '347', 4.0),
#  ('31', '348', 7.0),
#  ('31', '349', 8.0),
#  ('31', '350', 9.0),
#  ('31', '127', 7.0),
#  ('31', '312', 10.0),
#  ('31', '351', 7.0),
#  ('31', '352', 9.0),
#  ('32', '353', 7.0),
#  ('32', '354', 7.0),
#  ('32', '355', 7.0),
#  ('32', '356', 10.0),
#  ('32', '357', 8.0),
#  ('32', '358', 5.0),
#  ('32', '359', 5.0),
#  ('32', '360', 7.0),
#  ('32', '361', 7.0),
#  ('32', '362', 10.0),
#  ('32', '363', 7.0),
#  ('32', '364', 7.0),
#  ('32', '365', 9.0),
#  ('32', '366', 6.0),
#  ('32', '265', 8.0),
#  ('32', '367', 8.0),
#  ('32', '368', 9.0),
#  ('32', '369', 6.0),
#  ('32', '370', 5.0),
#  ('32', '371', 7.0),
#  ('32', '372', 6.0),
#  ('32', '373', 5.0),
#  ('32', '374', 5.0),
#  ('32', '375', 5.0),
#  ('33', '250', 10.0),
#  ('33', '376', 8.0),
#  ('33', '377', 9.0),
#  ('33', '378', 7.0),
#  ('33', '16', 10.0),
#  ('33', '379', 10.0),
#  ('33', '17', 9.0),
#  ('33', '380', 9.0),
#  ('33', '381', 8.0),
#  ('33', '382', 6.0),
#  ('33', '383', 8.0),
#  ('34', '384', 9.0),
#  ('34', '385', 8.0),
#  ('34', '60', 10.0),
#  ('34', '386', 8.0),
#  ('34', '387', 10.0),
#  ('34', '388', 9.0),
#  ('34', '389', 9.0),
#  ('34', '390', 7.0),
#  ('35', '391', 7.0),
#  ('35', '392', 3.0),
#  ('35', '393', 7.0),
#  ('35', '394', 5.0),
#  ('35', '395', 6.0),
#  ('35', '396', 8.0),
#  ('35', '397', 10.0),
#  ('35', '252', 8.0),
#  ('35', '398', 7.0),
#  ('35', '399', 8.0),
#  ('35', '400', 10.0),
#  ('35', '401', 8.0),
#  ('35', '259', 8.0),
#  ('35', '402', 10.0),
#  ('35', '403', 8.0),
#  ('35', '267', 8.0),
#  ('35', '404', 10.0),
#  ('36', '405', 10.0),
#  ('36', '406', 7.0),
#  ('36', '407', 2.0),
#  ('36', '408', 7.0),
#  ('36', '409', 7.0),
#  ('36', '410', 8.0),
#  ('36', '124', 9.0),
#  ('36', '411', 7.0),
#  ('36', '412', 7.0),
#  ('36', '413', 7.0),
#  ('36', '414', 9.0),
#  ('36', '415', 9.0),
#  ('36', '416', 8.0),
#  ('36', '417', 6.0),
#  ('36', '418', 5.0),
#  ('36', '419', 10.0),
#  ('36', '420', 8.0),
#  ('36', '421', 8.0),
#  ('36', '422', 9.0),
#  ('36', '423', 10.0),
#  ('36', '424', 9.0),
#  ('36', '425', 8.0),
#  ('36', '426', 7.0),
#  ('36', '427', 8.0),
#  ('37', '428', 9.0),
#  ('37', '429', 7.0),
#  ('37', '407', 8.0),
#  ('37', '409', 9.0),
#  ('37', '430', 8.0),
#  ('37', '431', 9.0),
#  ('37', '432', 7.0),
#  ('37', '433', 8.0),
#  ('37', '434', 8.0),
#  ('37', '435', 8.0),
#  ('37', '436', 9.0),
#  ('37', '241', 8.0),
#  ('38', '317', 8.0),
#  ('38', '437', 8.0),
#  ('38', '438', 7.0),
#  ('38', '439', 10.0),
#  ('38', '440', 3.0),
#  ('39', '441', 9.0),
#  ('39', '442', 9.0),
#  ('39', '443', 8.0),
#  ('39', '444', 8.0),
#  ('39', '445', 9.0),
#  ('39', '127', 10.0),
#  ('40', '446', 10.0),
#  ('40', '447', 7.0),
#  ('40', '243', 9.0),
#  ('40', '61', 9.0),
#  ('40', '411', 7.0),
#  ('40', '448', 10.0),
#  ('40', '449', 7.0),
#  ('40', '450', 9.0),
#  ('40', '451', 7.0),
#  ('40', '452', 9.0),
#  ('40', '453', 6.0),
#  ('40', '257', 6.0),
#  ('40', '454', 8.0),
#  ('40', '455', 5.0),
#  ('40', '456', 5.0),
#  ('41', '447', 7.0),
#  ('41', '457', 8.0),
#  ('41', '458', 9.0),
#  ('41', '459', 9.0),
#  ('41', '460', 8.0),
#  ('41', '456', 6.0),
#  ('41', '152', 6.0),
#  ('42', '461', 9.0),
#  ('42', '462', 7.0),
#  ('42', '463', 7.0),
#  ('42', '464', 5.0),
#  ('42', '465', 9.0),
#  ('42', '466', 5.0),
#  ('42', '467', 9.0),
#  ('42', '468', 8.0),
#  ('42', '469', 10.0),
#  ('42', '470', 9.0),
#  ('42', '431', 9.0),
#  ('42', '471', 9.0),
#  ('42', '338', 9.0),
#  ('42', '472', 9.0),
#  ('42', '339', 9.0),
#  ('42', '473', 9.0),
#  ('42', '474', 8.0),
#  ('42', '475', 6.0),
#  ('42', '476', 7.0),
#  ('42', '477', 9.0),
#  ('42', '478', 8.0),
#  ('42', '479', 8.0),
#  ('42', '480', 9.0),
#  ('42', '481', 9.0),
#  ('42', '482', 8.0),
#  ('42', '41', 7.0),
#  ('42', '192', 8.0),
#  ('42', '483', 8.0),
#  ('42', '484', 9.0),
#  ('43', '485', 8.0),
#  ('43', '486', 3.0),
#  ('43', '487', 6.0),
#  ('43', '488', 7.0),
#  ('43', '350', 10.0),
#  ('43', '489', 5.0),
#  ('43', '490', 7.0),
#  ('44', '491', 8.0),
#  ('44', '492', 8.0),
#  ('44', '493', 10.0),
#  ('44', '494', 3.0),
#  ('44', '495', 5.0),
#  ('45', '496', 10.0),
#  ('45', '497', 10.0),
#  ('45', '498', 10.0),
#  ('45', '499', 8.0),
#  ('45', '500', 10.0),
#  ('45', '501', 10.0),
#  ('46', '502', 9.0),
#  ('46', '503', 7.0),
#  ('46', '504', 8.0),
#  ('46', '505', 7.0),
#  ('46', '506', 8.0),
#  ('46', '507', 9.0),
#  ('47', '508', 9.0),
#  ('47', '509', 8.0),
#  ('47', '510', 7.0),
#  ('47', '465', 10.0),
#  ('47', '511', 9.0),
#  ('47', '512', 8.0),
#  ('47', '513', 9.0),
#  ('47', '514', 7.0),
#  ('47', '515', 7.0),
#  ('47', '191', 7.0),
#  ('47', '516', 7.0),
#  ('47', '517', 7.0),
#  ('47', '518', 7.0),
#  ('47', '519', 7.0),
#  ('47', '520', 9.0),
#  ('47', '521', 10.0),
#  ('47', '522', 10.0),
#  ('47', '523', 10.0),
#  ('47', '524', 10.0),
#  ('47', '525', 10.0),
#  ('47', '526', 7.0),
#  ('47', '527', 10.0),
#  ('47', '528', 8.0),
#  ('48', '529', 9.0),
#  ('48', '530', 10.0),
#  ('48', '531', 9.0),
#  ('48', '124', 10.0),
#  ('48', '532', 10.0),
#  ('48', '136', 9.0),
#  ('48', '533', 10.0),
#  ('48', '61', 10.0),
#  ('48', '534', 10.0),
#  ('48', '535', 9.0),
#  ('48', '233', 10.0),
#  ('48', '536', 10.0),
#  ('48', '537', 10.0),
#  ('48', '538', 9.0),
#  ('48', '539', 9.0),
#  ('48', '70', 10.0),
#  ('48', '540', 10.0),
#  ('48', '541', 9.0),
#  ('48', '542', 10.0),
#  ('48', '543', 9.0),
#  ('48', '544', 9.0),
#  ('48', '545', 10.0),
#  ('48', '546', 10.0),
#  ('48', '547', 8.0),
#  ('48', '548', 8.0),
#  ('48', '52', 7.0),
#  ('48', '549', 9.0),
#  ('48', '550', 10.0),
#  ('48', '551', 9.0),
#  ('48', '552', 7.0),
#  ('48', '553', 9.0),
#  ('48', '554', 9.0),
#  ('48', '102', 10.0),
#  ('48', '555', 10.0),
#  ('48', '556', 8.0),
#  ('49', '557', 8.0),
#  ('49', '558', 9.0),
#  ('49', '88', 8.0),
#  ('49', '559', 9.0),
#  ('49', '560', 7.0),
#  ('49', '561', 8.0),
#  ('49', '562', 8.0),
#  ('49', '563', 8.0),
#  ('49', '564', 2.0),
#  ('50', '565', 8.0),
#  ('50', '566', 7.0),
#  ('50', '567', 7.0),
#  ('50', '166', 6.0),
#  ('50', '568', 4.0),
#  ('50', '569', 7.0),
#  ('50', '570', 6.0),
#  ('51', '571', 9.0),
#  ('51', '572', 10.0),
#  ('51', '124', 3.0),
#  ('51', '573', 7.0),
#  ('51', '574', 10.0),
#  ('52', '575', 4.0),
#  ('52', '576', 7.0),
#  ('52', '577', 9.0),
#  ('52', '578', 9.0),
#  ('52', '579', 9.0),
#  ('53', '580', 10.0),
#  ('53', '581', 7.0),
#  ('53', '582', 9.0),
#  ('53', '583', 10.0),
#  ('53', '584', 10.0),
#  ('53', '585', 4.0),
#  ('53', '227', 9.0),
#  ('53', '586', 7.0),
#  ('53', '587', 10.0),
#  ('53', '588', 9.0),
#  ('53', '589', 8.0),
#  ('53', '590', 8.0),
#  ('53', '591', 8.0),
#  ('53', '592', 8.0),
#  ('53', '593', 10.0),
#  ('53', '594', 10.0),
#  ('54', '595', 5.0),
#  ('54', '596', 3.0),
#  ('54', '597', 7.0),
#  ('54', '598', 3.0),
#  ('54', '556', 5.0),
#  ('55', '599', 10.0),
#  ('55', '600', 10.0),
#  ('55', '601', 5.0),
#  ('55', '602', 7.0),
#  ('55', '158', 10.0),
#  ('55', '70', 10.0),
#  ('55', '603', 10.0),
#  ('55', '604', 10.0),
#  ('55', '185', 10.0),
#  ('55', '579', 6.0),
#  ('55', '605', 6.0),
#  ('55', '606', 8.0),
#  ('55', '607', 9.0),
#  ('55', '608', 10.0),
#  ('55', '609', 5.0),
#  ('55', '610', 10.0),
#  ('55', '611', 10.0),
#  ('55', '612', 4.0),
#  ('55', '613', 9.0),
#  ('55', '614', 10.0),
#  ('55', '192', 10.0),
#  ('55', '106', 5.0),
#  ('56', '615', 8.0),
#  ('56', '616', 5.0),
#  ('56', '617', 7.0),
#  ('56', '618', 8.0),
#  ('56', '619', 6.0),
#  ('56', '620', 6.0),
#  ('56', '621', 6.0),
#  ('56', '622', 10.0),
#  ('56', '623', 8.0),
#  ('56', '624', 8.0),
#  ('56', '625', 8.0),
#  ('57', '626', 8.0),
#  ('57', '581', 5.0),
#  ('57', '627', 10.0),
#  ('57', '628', 8.0),
#  ('57', '629', 9.0),
#  ('57', '630', 10.0),
#  ('57', '631', 9.0),
#  ('57', '632', 9.0),
#  ('57', '500', 9.0),
#  ('57', '426', 8.0),
#  ('57', '633', 8.0),
#  ('58', '465', 10.0),
#  ('58', '124', 7.0),
#  ('58', '634', 7.0),
#  ('58', '70', 7.0),
#  ('58', '635', 9.0),
#  ('58', '636', 10.0),
#  ('58', '637', 9.0),
#  ('58', '404', 5.0),
#  ('59', '638', 8.0),
#  ('59', '639', 7.0),
#  ('59', '640', 4.0),
#  ('59', '641', 6.0),
#  ('59', '642', 5.0),
#  ('60', '643', 4.0),
#  ('60', '316', 7.0),
#  ('60', '644', 6.0),
#  ('60', '645', 6.0),
#  ('60', '646', 3.0),
#  ('61', '207', 8.0),
#  ('61', '486', 7.0),
#  ('61', '647', 8.0),
#  ('61', '648', 7.0),
#  ('61', '649', 7.0),
#  ('61', '650', 8.0),
#  ('61', '651', 6.0),
#  ('61', '652', 7.0),
#  ('61', '653', 7.0),
#  ('61', '654', 9.0),
#  ('61', '655', 7.0),
#  ('61', '656', 8.0),
#  ('61', '657', 7.0),
#  ('61', '658', 5.0),
#  ('61', '659', 7.0),
#  ('61', '660', 7.0),
#  ('61', '661', 6.0),
#  ('61', '662', 7.0),
#  ('61', '663', 7.0),
#  ('61', '664', 7.0),
#  ('61', '665', 7.0),
#  ('62', '666', 7.0),
#  ('62', '667', 8.0),
#  ('62', '668', 6.0),
#  ('62', '669', 10.0),
#  ('62', '476', 9.0),
#  ('62', '670', 9.0),
#  ('62', '671', 7.0),
#  ('63', '672', 10.0),
#  ('63', '673', 5.0),
#  ('63', '674', 5.0),
#  ('63', '675', 8.0),
#  ('63', '676', 9.0),
#  ('64', '677', 7.0),
#  ('64', '678', 9.0),
#  ('64', '679', 8.0),
#  ('64', '680', 8.0),
#  ('64', '70', 9.0),
#  ('64', '132', 8.0),
#  ('64', '681', 8.0),
#  ('64', '682', 8.0),
#  ('65', '61', 8.0),
#  ('65', '683', 7.0),
#  ('65', '684', 6.0),
#  ('65', '590', 7.0),
#  ('65', '685', 8.0),
#  ('66', '686', 8.0),
#  ('66', '288', 8.0),
#  ('66', '505', 9.0),
#  ('66', '687', 6.0),
#  ('66', '688', 5.0),
#  ('67', '227', 9.0),
#  ('67', '689', 9.0),
#  ('67', '68', 9.0),
#  ('67', '690', 9.0),
#  ('67', '691', 9.0),
#  ('68', '692', 7.0),
#  ('68', '693', 7.0),
#  ('68', '176', 8.0),
#  ('68', '694', 6.0),
#  ('68', '695', 5.0),
#  ('68', '678', 8.0),
#  ('68', '696', 7.0),
#  ('68', '697', 6.0),
#  ('68', '698', 8.0),
#  ('68', '699', 7.0),
#  ('68', '700', 8.0),
#  ('68', '701', 8.0),
#  ('68', '702', 6.0),
#  ('68', '449', 7.0),
#  ('68', '703', 7.0),
#  ('68', '53', 8.0),
#  ('68', '704', 8.0),
#  ('68', '705', 7.0),
#  ('68', '637', 8.0),
#  ('68', '285', 6.0),
#  ('69', '446', 10.0),
#  ('69', '706', 5.0),
#  ('69', '707', 5.0),
#  ('69', '708', 5.0),
#  ('69', '709', 10.0),
#  ('69', '710', 5.0),
#  ('69', '711', 10.0),
#  ('69', '657', 8.0),
#  ('69', '712', 7.0),
#  ('69', '179', 4.0),
#  ('69', '713', 10.0),
#  ('69', '714', 10.0),
#  ('69', '715', 4.0),
#  ('69', '500', 8.0),
#  ('69', '716', 5.0),
#  ('69', '717', 9.0),
#  ('69', '352', 10.0),
#  ('69', '20', 5.0),
#  ('69', '456', 10.0),
#  ('69', '718', 4.0),
#  ('70', '719', 1.0),
#  ('70', '650', 8.0),
#  ('70', '720', 5.0),
#  ('70', '721', 8.0),
#  ('70', '722', 7.0),
#  ('70', '723', 8.0),
#  ('70', '590', 8.0),
#  ('70', '724', 8.0),
#  ('70', '725', 9.0),
#  ('70', '726', 8.0),
#  ('71', '727', 7.0),
#  ('71', '63', 7.0),
#  ('71', '728', 6.0),
#  ('71', '729', 6.0),
#  ('71', '730', 8.0),
#  ('71', '731', 6.0),
#  ('71', '732', 7.0),
#  ('71', '733', 7.0),
#  ('71', '7', 4.0),
#  ('72', '734', 6.0),
#  ('72', '735', 3.0),
#  ('72', '736', 6.0),
#  ('72', '737', 5.0),
#  ('72', '738', 6.0),
#  ('72', '739', 7.0),
#  ('73', '740', 10.0),
#  ('73', '741', 9.0),
#  ('73', '742', 7.0),
#  ('73', '743', 7.0),
#  ('73', '744', 10.0),
#  ('73', '745', 10.0),
#  ('73', '746', 10.0),
#  ('73', '747', 10.0),
#  ('73', '748', 10.0),
#  ('73', '749', 5.0),
#  ('73', '750', 10.0),
#  ('73', '751', 8.0),
#  ('73', '752', 10.0),
#  ('74', '753', 9.0),
#  ('74', '651', 5.0),
#  ('74', '754', 5.0),
#  ('74', '755', 10.0),
#  ('74', '601', 9.0),
#  ('74', '756', 10.0),
#  ('74', '757', 6.0),
#  ('74', '758', 9.0),
#  ('74', '759', 7.0),
#  ('74', '760', 9.0),
#  ('74', '761', 7.0),
#  ('74', '762', 5.0),
#  ('74', '323', 7.0),
#  ('74', '763', 8.0),
#  ('74', '764', 9.0),
#  ('74', '765', 7.0),
#  ('74', '766', 7.0),
#  ('74', '767', 7.0),
#  ('74', '434', 10.0),
#  ('74', '768', 9.0),
#  ('74', '769', 5.0),
#  ('74', '770', 8.0),
#  ('74', '20', 1.0),
#  ('74', '771', 7.0),
#  ('74', '772', 7.0),
#  ('74', '773', 6.0),
#  ('75', '638', 5.0),
#  ('75', '227', 10.0),
#  ('75', '774', 10.0),
#  ('75', '775', 9.0),
#  ('75', '776', 8.0),
#  ('75', '777', 8.0),
#  ('75', '778', 9.0),
#  ('75', '620', 5.0),
#  ('75', '779', 10.0),
#  ('75', '780', 10.0),
#  ('75', '781', 10.0),
#  ('75', '782', 10.0),
#  ('75', '783', 8.0),
#  ('75', '784', 8.0),
#  ('76', '586', 10.0),
#  ('76', '785', 10.0),
#  ('76', '786', 10.0),
#  ('76', '787', 2.0),
#  ('76', '788', 6.0),
#  ('76', '789', 10.0),
#  ('76', '790', 1.0),
#  ('76', '791', 6.0),
#  ('76', '784', 10.0),
#  ('77', '792', 6.0),
#  ('77', '793', 5.0),
#  ('77', '794', 10.0),
#  ('77', '795', 8.0),
#  ('77', '796', 5.0),
#  ('77', '797', 8.0),
#  ('77', '798', 9.0),
#  ('78', '799', 9.0),
#  ('78', '800', 8.0),
#  ('78', '801', 8.0),
#  ('78', '802', 6.0),
#  ('78', '803', 10.0),
#  ('78', '804', 5.0),
#  ('78', '52', 2.0),
#  ('78', '805', 8.0),
#  ('79', '806', 10.0),
#  ('79', '807', 10.0),
#  ('79', '808', 10.0),
#  ('79', '809', 10.0),
#  ('79', '810', 10.0),
#  ('79', '629', 10.0),
#  ('79', '811', 10.0),
#  ('79', '812', 10.0),
#  ('79', '813', 10.0),
#  ('79', '814', 10.0),
#  ('79', '815', 10.0),
#  ('80', '816', 10.0),
#  ('80', '817', 10.0),
#  ('80', '818', 10.0),
#  ('80', '819', 10.0),
#  ('80', '820', 8.0),
#  ('80', '821', 8.0),
#  ('80', '627', 10.0),
#  ('80', '274', 5.0),
#  ('80', '822', 10.0),
#  ('80', '823', 10.0),
#  ('80', '824', 6.0),
#  ('80', '471', 9.0),
#  ('80', '472', 9.0),
#  ('80', '473', 9.0),
#  ('80', '341', 9.0),
#  ('80', '825', 10.0),
#  ('80', '826', 10.0),
#  ('80', '827', 10.0),
#  ('80', '828', 10.0),
#  ('80', '829', 6.0),
#  ('80', '830', 10.0),
#  ('80', '831', 8.0),
#  ('80', '480', 9.0),
#  ('80', '832', 6.0),
#  ('80', '833', 8.0),
#  ('80', '834', 10.0),
#  ('80', '835', 10.0),
#  ('80', '836', 8.0),
#  ('80', '837', 8.0),
#  ('80', '838', 8.0),
#  ('80', '839', 8.0),
#  ('80', '840', 10.0),
#  ('80', '841', 10.0),
#  ('80', '842', 10.0),
#  ('80', '843', 10.0),
#  ('80', '844', 9.0),
#  ('80', '845', 10.0),
#  ('80', '846', 10.0),
#  ('80', '847', 10.0),
#  ('80', '848', 10.0),
#  ('80', '849', 10.0),
#  ('80', '850', 10.0),
#  ('80', '851', 9.0),
#  ('80', '852', 10.0),
#  ('80', '853', 10.0),
#  ('80', '854', 8.0),
#  ('80', '855', 10.0),
#  ('80', '856', 9.0),
#  ('80', '857', 10.0),
#  ('80', '858', 10.0),
#  ('81', '859', 7.0),
#  ('81', '67', 7.0),
#  ('81', '624', 8.0),
#  ('81', '860', 5.0),
#  ('81', '861', 1.0),
#  ('82', '862', 7.0),
#  ('82', '863', 8.0),
#  ('82', '458', 5.0),
#  ('82', '572', 8.0),
#  ('82', '864', 10.0),
#  ('82', '865', 10.0),
#  ('82', '866', 10.0),
#  ('82', '867', 10.0),
#  ('82', '868', 10.0),
#  ('82', '869', 6.0),
#  ('82', '870', 9.0),
#  ('82', '871', 8.0),
#  ('82', '688', 8.0),
#  ('82', '222', 5.0),
#  ('82', '403', 3.0),
#  ('82', '872', 9.0),
#  ('82', '434', 10.0),
#  ...]

# %%
# Split the data based on ratio
rs = RatioSplit(data=data, test_size=0.2, rating_threshold=1.0, seed=123)

# %%
# initialize models, here we are comparing: simple, traditional, and neural networks based models
models = [
          # 1: Random
          # 2: MostPop
          MostPop(),
          # 3: UserKNN
          # 4: BPR
          BPR(k=10, max_iter=200, learning_rate=0.001, lambda_reg=0.01, seed=123),
          # 5: MF
          MF(k=30, max_iter=100, learning_rate=0.01, lambda_reg=0.001, seed=123),
          # 6: PMF
          PMF(k=10, max_iter=100, learning_rate=0.001, lambda_reg=0.001),
          # 7: NMF
          NMF(k=15, max_iter=50, learning_rate=0.005, lambda_u=0.06, lambda_v=0.06, lambda_bu=0.02, lambda_bi=0.02, use_bias=False, verbose=True, seed=123),
          # 8: WMF
          WMF(k=50, max_iter=50, learning_rate=0.001, lambda_u=0.01, lambda_v=0.01, verbose=True, seed=123),
          # 9: PF
          HPF(k=50, seed=123, hierarchical=False, name="PF"),
          # 10: NueMF
          NeuMF(num_factors=8, layers=[32, 16, 8], act_fn="tanh", num_epochs=1, num_neg=3, batch_size=256, lr=0.001, seed=42, verbose=True),
          # 11: VAECF
          VAECF(k=10, autoencoder_structure=[20], act_fn="tanh", likelihood="mult", n_epochs=100, batch_size=100, learning_rate=0.001, beta=1.0, seed=123, use_gpu=True, verbose=True)
          ]

# %%
# define metrics to evaluate the models
metrics = [MAE(), MSE(), RMSE(), AUC(), MAP(), MRR(), 
           Precision(k=5), Precision(k=10), Precision(k=20), Precision(k=50),
           Recall(k=5), Recall(k=10), Recall(k=20), Recall(k=50),
           NDCG(k=5), NDCG(k=10), NDCG(k=20), NDCG(k=50),
           FMeasure(k=5), FMeasure(k=10), FMeasure(k=20), FMeasure(k=50)]

# put it together in an experiment, voilà!
exp = cornac.Experiment(eval_method=rs, models=models, metrics=metrics, user_based=True)
exp.run()
# Out:
# Requirement already satisfied: tensorflow in h:\anaconda\envs\tf15\lib\site-packages (1.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp37-cp37m-win_amd64.whl (266.3 MB)
#      -------------------------------------- 266.3/266.3 MB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: packaging in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: setuptools in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.5.0)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting libclang>=13.0.0
#   Downloading libclang-15.0.6.1-py2.py3-none-win_amd64.whl (23.2 MB)
#      --------------------------------------- 23.2/23.2 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: numpy>=1.20 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp37-cp37m-win_amd64.whl (896 kB)
#      ------------------------------------- 896.6/896.6 kB 14.1 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.29.0-cp37-cp37m-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 15.7 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Requirement already satisfied: h5py>=2.9.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.42.0)
# Collecting tensorboard<2.12,>=2.11
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Requirement already satisfied: six>=1.12.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.1.4-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in h:\anaconda\envs\tf15\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in h:\anaconda\envs\tf15\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in h:\anaconda\envs\tf15\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.6.0)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ---------------------------------------- 232.7/232.7 kB ? eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in h:\anaconda\envs\tf15\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in h:\anaconda\envs\tf15\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in h:\anaconda\envs\tf15\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in h:\anaconda\envs\tf15\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in h:\anaconda\envs\tf15\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in h:\anaconda\envs\tf15\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in h:\anaconda\envs\tf15\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.11.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in h:\anaconda\envs\tf15\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in h:\anaconda\envs\tf15\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in h:\anaconda\envs\tf15\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in h:\anaconda\envs\tf15\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in h:\anaconda\envs\tf15\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in h:\anaconda\envs\tf15\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in h:\anaconda\envs\tf15\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in h:\anaconda\envs\tf15\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Installing collected packages: libclang, flatbuffers, werkzeug, tensorflow-io-gcs-filesystem, tensorflow-estimator, protobuf, keras, astunparse, absl-py, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 0.16.1
#     Uninstalling Werkzeug-0.16.1:
#       Successfully uninstalled Werkzeug-0.16.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.15.0
#     Uninstalling absl-py-0.15.0:
#       Successfully uninstalled absl-py-0.15.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'h:\\anaconda\\envs\\tf15\\lib\\site-packages\\~ensorflow_core\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Optimization finished!
#   0%|          | 0/50 [00:00<?, ?it/s]
# Learning completed!
# Learning...
# Learning completed!
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\155970620.py", line 10, in <module>
#     exp.run()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\experiment\experiment.py", line 135, in run
#     show_validation=self.show_validation,
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\eval_methods\base_method.py", line 700, in evaluate
#     model.fit(self.train_set, self.val_set)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_ncf_base.py", line 127, in fit
#     self._build_graph()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 155, in _build_graph
#     import tensorflow.compat.v1 as tf
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ModuleNotFoundError: No module named 'tensorflow_core.compat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\155970620.py", line 10, in <module>
#     exp.run()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\experiment\experiment.py", line 135, in run
#     show_validation=self.show_validation,
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\eval_methods\base_method.py", line 700, in evaluate
#     model.fit(self.train_set, self.val_set)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_ncf_base.py", line 127, in fit
#     self._build_graph()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 155, in _build_graph
#     import tensorflow.compat.v1 as tf
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ModuleNotFoundError: No module named 'tensorflow_core.compat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\155970620.py", line 10, in <module>
#     exp.run()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\experiment\experiment.py", line 135, in run
#     show_validation=self.show_validation,
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\eval_methods\base_method.py", line 700, in evaluate
#     model.fit(self.train_set, self.val_set)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_ncf_base.py", line 127, in fit
#     self._build_graph()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 155, in _build_graph
#     import tensorflow.compat.v1 as tf
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ModuleNotFoundError: No module named 'tensorflow_core.compat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'

# %%
def compute_user_knn(C):
  ctime = time.time()
  print("Training User-based Collaborative Filtering...", )

  sim = C.dot(C.T)
  norms = [norm(C[i]) for i in range(C.shape[0])]

  for i in tqdm(range(C.shape[0])):
    sim[i][i] = 0.0
    for j in range(i+1, C.shape[0]):
      sim[i][j] /= (norms[i] * norms[j])
      sim[j][i] /= (norms[i] * norms[j])

  print("Done. Elapsed time:", time.time() - ctime, "s")
  rec_score = sim.dot(C)
  return rec_score
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 37

# %%
def read_training_data():
  training_matrix = np.zeros((rs.train_set.matrix.shape[0], rs.train_set.matrix.shape[1]))
  for uid in tqdm(rs.train_set.uid_map.values()):
    for iid in rs.train_set.iid_map.values():
      training_matrix[uid, iid] = rs.train_set.matrix[uid, iid]
  return training_matrix

# %%
# creating users-books rating matrix (will be used for User-KNN algorithm)
training_matrix = read_training_data()
# Out:
# 100%|██████████| 6358/6358 [09:56<00:00, 10.67it/s]

# %%
# running User-KNN algorithms and getting the user-book scores
user_knn_scores = compute_user_knn(training_matrix)
# Out:
# Training User-based Collaborative Filtering...
# 100%|██████████| 6358/6358 [00:12<00:00, 501.41it/s]
# Done. Elapsed time: 14.054950714111328 s

# %%
# UserKNN recommendation algorithm
def get_top_n_UserKNN(n=10):
    print("User-KNN model is selected:")
    top_n = defaultdict(list)
    # test_items = list(rs.test_set.iid_map.keys())
    for uid in rs.train_set.uid_map.values():
      user_id = list(rs.train_set.user_ids)[uid]
      top_n_items_idxs = list(reversed(user_knn_scores[uid].argsort()))[:n]
      for iid in top_n_items_idxs:
        item_id = list(rs.train_set.item_ids)[iid]
        top_n[int(user_id)].append((int(item_id), user_knn_scores[uid][iid]))
    return top_n
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 38
# ERROR! Session/line number was not unique in database. History logging moved to new session 43

# %%
def get_top_n(algo_name, n=10):
  for model in exp.models:
    if model.name == algo_name:
      print(model.name + " model is selected:")
      top_n = defaultdict(list)
      for uid in model.train_set.uid_map.values():
        user_id = list(model.train_set.user_ids)[uid]
        try:
          item_rank = model.rank(user_idx=uid)[0]
        except:
          item_rank = model.rank(user_idx=int(uid))[0]
        # collect top N items
        item_rank_top = item_rank[:n]
        for iid in item_rank_top:
          item_id = list(model.train_set.item_ids)[iid]
          top_n[int(user_id)].append((int(item_id), model.score(uid, iid)))
  return top_n

# %%
# random recommendation algorithm
def get_top_n_random(n=10):
    print("Random model is selected:")
    top_n = defaultdict(list)
    test_items = list(rs.test_set.iid_map.keys())
    for uid in rs.train_set.uid_map.values():
      if uid not in top_n.keys():
        user_id = list(rs.train_set.user_ids)[uid]
        for i in range(0, n):
          top_n[int(user_id)].append((int(rd.choice(test_items)), i))
    return top_n

# %%
# create item dataframe with normalized item counts
df_item_dist = pd.DataFrame(item_dist)
df_item_dist.columns = [feedback_column]
df_item_dist[feedback_column] /= no_users
df_item_dist.head()
# Out:
#        rating
# 124  0.055049
# 70   0.043567
# 50   0.031299
# 465  0.029569
# 581  0.028311
#        rating
# 124  0.055049
# 70   0.043567
# 50   0.031299
# 465  0.029569
# 581  0.028311

# %%
algo_names = ['Random', 'MostPop', 'UserKNN', 'MF', 'PMF', 'BPR', 'NMF', 'WMF', 'PF', 'NeuMF', 'VAECF']

i = 0
low_rec_gap_list = [] # one entry per algorithmus
medium_rec_gap_list = []
high_rec_gap_list = []

for i in range(0, len(algo_names)):
    df_item_dist[algo_names[i]] = 0
    low_rec_gap = 0
    medium_rec_gap = 0
    high_rec_gap = 0
    
    if algo_names[i] == 'Random':
      top_n = get_top_n_random(n=10)
    elif algo_names[i] == 'UserKNN':
      top_n = get_top_n_UserKNN(n=10)
    else:
      top_n = get_top_n(algo_names[i], n=10)
    low_count = 0
    med_count = 0
    high_count = 0
    for uid, user_ratings in top_n.items():
        iid_list = []
        for (iid, _) in user_ratings:
            df_item_dist.loc[iid, algo_names[i]] += 1
            iid_list.append(iid)
        gap = sum(item_dist[iid_list] / no_users) / len(iid_list)
        if uid in low_users.index:
            low_rec_gap += gap
            low_count += 1
        elif uid in medium_users.index:
            medium_rec_gap += gap
            med_count += 1
        elif uid in high_users.index:
            high_rec_gap += gap
            high_count += 1
    low_rec_gap_list.append(low_rec_gap / low_count)
    medium_rec_gap_list.append(medium_rec_gap / med_count)
    high_rec_gap_list.append(high_rec_gap / high_count)
    i += 1 # next algorithm
# Out:
# MF model is selected:
# PMF model is selected:
# BPR model is selected:
# NMF model is selected:
# WMF model is selected:
# PF model is selected:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# NeuMF model is selected:
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Random model is selected:
# MostPop model is selected:
# User-KNN model is selected:
# MF model is selected:
# PMF model is selected:
# BPR model is selected:
# NMF model is selected:
# WMF model is selected:
# PF model is selected:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# NeuMF model is selected:
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Random model is selected:
# MostPop model is selected:
# User-KNN model is selected:
# MF model is selected:
# PMF model is selected:
# BPR model is selected:
# NMF model is selected:
# WMF model is selected:
# PF model is selected:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# NeuMF model is selected:
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 9, in get_top_n
#     item_rank = model.rank(user_idx=uid)[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\3564967531.py", line 19, in <module>
#     top_n = get_top_n(algo_names[i], n=10)
#   File "H:\TEMP\ipykernel_8288\3550572607.py", line 11, in get_top_n
#     item_rank = model.rank(user_idx=int(uid))[0]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\recommender.py", line 258, in rank
#     known_item_scores = self.score(user_idx)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\cornac\models\ncf\recom_neumf.py", line 282, in score
#     known_item_scores = self.sess.run(
# AttributeError: 'NeuMF' object has no attribute 'sess'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'

# %%
sns.set(rc = {'figure.figsize':(5,4)})
for i in range(0, len(algo_names)):
    plt.figure()
    x = df_item_dist[feedback_column]
    y = df_item_dist[algo_names[i]]

    plt.plot(x, y, 'o')
    plt.xlabel('Book popularity', fontsize='15')
    plt.ylabel('Recommendation frequency', fontsize='15')
    plt.xticks(fontsize='13')
    plt.yticks(fontsize='13')
    plt.savefig('rec_' + algo_names[i] + '.pdf', dpi=300, bbox_inches='tight')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 39
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\indexes\base.py", line 3361, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 76, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5198, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5206, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'VAECF'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\512759413.py", line 5, in <module>
#     y = df_item_dist[algo_names[i]]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\frame.py", line 3458, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\indexes\base.py", line 3363, in get_loc
#     raise KeyError(key) from err
# KeyError: 'VAECF'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\indexes\base.py", line 3361, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 76, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5198, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5206, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'VAECF'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\512759413.py", line 5, in <module>
#     y = df_item_dist[algo_names[i]]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\frame.py", line 3458, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\indexes\base.py", line 3363, in get_loc
#     raise KeyError(key) from err
# KeyError: 'VAECF'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\indexes\base.py", line 3361, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 76, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5198, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5206, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'VAECF'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\512759413.py", line 5, in <module>
#     y = df_item_dist[algo_names[i]]
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\frame.py", line 3458, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\pandas\core\indexes\base.py", line 3363, in get_loc
#     raise KeyError(key) from err
# KeyError: 'VAECF'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 44
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\512759413.py", line 12, in <module>
#     plt.savefig('rec_' + algo_names[i] + '.pdf', dpi=300, bbox_inches='tight')
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\pyplot.py", line 977, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\figure.py", line 3058, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backend_bases.py", line 2325, in print_figure
#     **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backend_bases.py", line 1648, in wrapper
#     return func(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\_api\deprecation.py", line 389, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backends\backend_pdf.py", line 2783, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backends\backend_pdf.py", line 654, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\cbook\__init__.py", line 451, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
# PermissionError: [Errno 13] Permission denied: 'rec_Random.pdf'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\512759413.py", line 12, in <module>
#     plt.savefig('rec_' + algo_names[i] + '.pdf', dpi=300, bbox_inches='tight')
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\pyplot.py", line 977, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\figure.py", line 3058, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backend_bases.py", line 2325, in print_figure
#     **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backend_bases.py", line 1648, in wrapper
#     return func(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\_api\deprecation.py", line 389, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backends\backend_pdf.py", line 2783, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backends\backend_pdf.py", line 654, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\cbook\__init__.py", line 451, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
# PermissionError: [Errno 13] Permission denied: 'rec_Random.pdf'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\512759413.py", line 12, in <module>
#     plt.savefig('rec_' + algo_names[i] + '.pdf', dpi=300, bbox_inches='tight')
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\pyplot.py", line 977, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\figure.py", line 3058, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backend_bases.py", line 2325, in print_figure
#     **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backend_bases.py", line 1648, in wrapper
#     return func(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\_api\deprecation.py", line 389, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backends\backend_pdf.py", line 2783, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\backends\backend_pdf.py", line 654, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\matplotlib\cbook\__init__.py", line 451, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
# PermissionError: [Errno 13] Permission denied: 'rec_Random.pdf'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'

# %%
low_gap_vals = []
medium_gap_vals = []
high_gap_vals = []

for i in range(0, len(algo_names)):
    low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
    medium_gap_vals.append((medium_rec_gap_list[i] - medium_gap) / medium_gap * 100)
    high_gap_vals.append((high_rec_gap_list[i] - high_gap) / high_gap * 100)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\270173408.py", line 6, in <module>
#     low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR! Session/line number was not unique in database. History logging moved to new session 40
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\270173408.py", line 6, in <module>
#     low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\270173408.py", line 6, in <module>
#     low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\270173408.py", line 6, in <module>
#     low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR! Session/line number was not unique in database. History logging moved to new session 45
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\270173408.py", line 6, in <module>
#     low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\270173408.py", line 6, in <module>
#     low_gap_vals.append((low_rec_gap_list[i] - low_gap) / low_gap * 100)
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'

# %%
sns.set(rc = {'figure.figsize':(8,4)})

# set width of bar
barWidth = 0.07

# set height of bar
bars1 = [low_gap_vals[0], medium_gap_vals[0], high_gap_vals[0]]
bars2 = [low_gap_vals[1], medium_gap_vals[1], high_gap_vals[1]]
bars3 = [low_gap_vals[2], medium_gap_vals[2], high_gap_vals[2]]
bars4 = [low_gap_vals[3], medium_gap_vals[3], high_gap_vals[3]]
bars5 = [low_gap_vals[4], medium_gap_vals[4], high_gap_vals[4]]
bars6 = [low_gap_vals[5], medium_gap_vals[5], high_gap_vals[5]]
bars7 = [low_gap_vals[6], medium_gap_vals[6], high_gap_vals[6]]
bars8 = [low_gap_vals[7], medium_gap_vals[7], high_gap_vals[7]]
bars9 = [low_gap_vals[8], medium_gap_vals[8], high_gap_vals[8]]
bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
bars11 = [low_gap_vals[10], medium_gap_vals[10], high_gap_vals[10]]

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]
r7 = [x + barWidth for x in r6]
r8 = [x + barWidth for x in r7]
r9 = [x + barWidth for x in r8]
r10 = [x + barWidth for x in r9]
r11 = [x + barWidth for x in r10]
# r12 = [x + barWidth for x in r11]
# r13 = [x + barWidth for x in r12]

# ['Random', 'MostPop', 'UserKNN', 'MF', 'PMF', 'BPR', 'NMF', 'WMF', 'PF', 'NeuMF', 'VAECF']
patterns = [ "/" , "\\" , "|" , "-" , "+" , "x", "o", "O", ".", "*", "--"]

# Make the plot
plt.bar(r1, bars1, width=barWidth, label='Random', hatch=patterns[0])
plt.bar(r2, bars2, width=barWidth, label='MostPop', hatch=patterns[1])
plt.bar(r3, bars3, width=barWidth, label='UserKNN', hatch=patterns[2])
plt.bar(r4, bars4, width=barWidth, label='MF', hatch=patterns[3])
plt.bar(r5, bars5, width=barWidth, label='PMF', hatch=patterns[4])
plt.bar(r6, bars6, width=barWidth, label='BPR', hatch=patterns[5])
plt.bar(r7, bars7, width=barWidth, label='NMF', hatch=patterns[6])
plt.bar(r8, bars8, width=barWidth, label='WMF', hatch=patterns[7])
plt.bar(r9, bars9, width=barWidth, label='PF', hatch=patterns[8])
plt.bar(r10, bars10, width=barWidth, label='NeuMF', hatch=patterns[9])
plt.bar(r11, bars11, width=barWidth, label='VAECF', hatch=patterns[10])

# Add xticks on the middle of the group bars + show legend
plt.xlabel('User group', fontsize='14')
plt.ylabel('% $\Delta$ GAP', fontsize='14')
plt.xticks([r + barWidth + 0.3 for r in range(len(bars1))], ['Niche', 'Diverse', 'BestSeller'], fontsize='13')
plt.yticks(fontsize='10')
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0., framealpha=1, fontsize='12')
plt.savefig('gap_analysis.pdf', dpi=300, bbox_inches='tight')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\971293223.py", line 16, in <module>
#     bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR! Session/line number was not unique in database. History logging moved to new session 41
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\971293223.py", line 16, in <module>
#     bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\971293223.py", line 16, in <module>
#     bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\971293223.py", line 16, in <module>
#     bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# ERROR! Session/line number was not unique in database. History logging moved to new session 46
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\971293223.py", line 16, in <module>
#     bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\971293223.py", line 16, in <module>
#     bars10 = [low_gap_vals[9], medium_gap_vals[9], high_gap_vals[9]]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'

# %%
# analysis on different users groups based on the NDCG@10
# reult have difference parameter and show the values of evaluation includes per user performance on each evaluation metrics

print("User groups evaluation is started ...")

niche_users = list()
divers_users = list()
focused_users = list()

metric_group_results = defaultdict(list)
metric_group_results['MAE'] = list()
metric_group_results['Precision@10'] = list()
metric_group_results['Recall@10'] = list()
metric_group_results['NDCG@10'] = list()

ttest_group_results = defaultdict(list)
ttest_group_results['MAE'] = list()
ttest_group_results['Precision@10'] = list()
ttest_group_results['Recall@10'] = list()
ttest_group_results['NDCG@10'] = list()

for eachresult in exp.result:
  print("> " + eachresult.model_name)
  user_results = eachresult.metric_user_results # <- this is a dictionary
  for metric in exp.metrics:
    for user_idx, user_performance in user_results[metric.name].items():
      user_id = int(list(rs.train_set.user_ids)[user_idx])
      if user_id in low_users.index:
        niche_users.append(user_performance)
      elif user_id in medium_users.index:
        divers_users.append(user_performance)
      elif user_id in high_users.index:
        focused_users.append(user_performance)
      else:
        print("Oops! We could not find a user!")

    print(metric.name + ": " + str(round(np.mean(niche_users), 4)) + "," + str(round(np.mean(divers_users), 4)) + "," + str(round(np.mean(focused_users), 4)))
    if metric.name in metric_group_results.keys():
      metric_group_results[metric.name].append((round(np.mean(niche_users), 4),
                                                round(np.mean(divers_users), 4),
                                                round(np.mean(focused_users), 4)))
      
      ttest_group_results[metric.name].append((round(stats.ttest_ind(niche_users, divers_users)[1], 8),
                                               round(stats.ttest_ind(niche_users, focused_users)[1], 8),
                                              round(stats.ttest_ind(divers_users, focused_users)[1], 8)))

    print(stats.ttest_ind(niche_users, focused_users))
    niche_users.clear()
    divers_users.clear()
    focused_users.clear()
  print()
# Out:
# User groups evaluation is started ...
# > MostPop
# ERROR! Session/line number was not unique in database. History logging moved to new session 42
# MAE: 2.783,2.492,2.2878
# Ttest_indResult(statistic=7.435886545867454, pvalue=1.5136696550071922e-13)
# MSE: 11.7564,9.8648,8.5401
# Ttest_indResult(statistic=7.2084482543848045, pvalue=7.90077178584305e-13)
# RMSE: 3.0491,2.7949,2.4931
# Ttest_indResult(statistic=8.16753585321936, pvalue=5.417120323531059e-16)
# AUC: 0.4565,0.6504,0.8367
# Ttest_indResult(statistic=-38.68671438668353, pvalue=9.523758201539388e-247)
# MAP: 0.0039,0.0137,0.0322
# Ttest_indResult(statistic=-8.944187413421709, pvalue=8.12395520430788e-19)
# MRR: 0.0088,0.0377,0.0632
# Ttest_indResult(statistic=-9.316096299920646, pvalue=2.9901590689904625e-20)
# Precision@5: 0.0021,0.0096,0.0176
# Ttest_indResult(statistic=-7.812383257669373, pvalue=8.858433085942772e-15)
# Precision@10: 0.0017,0.0084,0.0128
# Ttest_indResult(statistic=-9.057291314365356, pvalue=3.0144369007543546e-19)
# Precision@20: 0.0015,0.0071,0.0101
# Ttest_indResult(statistic=-10.999975511097023, pvalue=2.1640913669642567e-27)
# Precision@50: 0.0012,0.0055,0.0073
# Ttest_indResult(statistic=-14.261750488110026, pvalue=4.3650432953913717e-44)
# Recall@5: 0.005,0.013,0.0373
# Ttest_indResult(statistic=-6.484883139605801, pvalue=1.107758598583287e-10)
# Recall@10: 0.0077,0.0232,0.0553
# Ttest_indResult(statistic=-7.87922340343382, pvalue=5.280982079825996e-15)
# Recall@20: 0.0128,0.0381,0.0857
# Ttest_indResult(statistic=-9.876504340749628, pvalue=1.644757031553074e-22)
# Recall@50: 0.0225,0.0733,0.1453
# Ttest_indResult(statistic=-13.297750809217671, pvalue=8.92212728516134e-39)
# NDCG@5: 0.0034,0.0136,0.032
# Ttest_indResult(statistic=-7.1676902398073, pvalue=1.0571005659479935e-12)
# NDCG@10: 0.0043,0.0169,0.0382
# Ttest_indResult(statistic=-8.255445689960375, pvalue=2.6656235413147095e-16)
# NDCG@20: 0.006,0.0219,0.0477
# Ttest_indResult(statistic=-9.79652891049462, pvalue=3.513751887242722e-22)
# NDCG@50: 0.0085,0.0319,0.0631
# Ttest_indResult(statistic=-12.326601979197116, pvalue=9.684797271946846e-34)
# F1@5: 0.0026,0.0094,0.0218
# Ttest_indResult(statistic=-7.71672664067964, pvalue=1.844204951724181e-14)
# F1@10: 0.0026,0.0109,0.0193
# Ttest_indResult(statistic=-9.255803881774943, pvalue=5.1492848896206834e-20)
# F1@20: 0.0025,0.0109,0.0172
# Ttest_indResult(statistic=-11.307000329179973, pvalue=8.345716243709952e-29)
# F1@50: 0.0021,0.0097,0.0135
# Ttest_indResult(statistic=-14.589027179952312, pvalue=5.867069787413548e-46)
#
# > BPR
# MAE: 6.7712,6.5882,6.4793
# Ttest_indResult(statistic=4.355839815426434, pvalue=1.3904539020886894e-05)
# MSE: 49.1674,46.7407,45.217
# Ttest_indResult(statistic=4.818509748253695, pvalue=1.5515973129193404e-06)
# RMSE: 6.8474,6.6915,6.5615
# Ttest_indResult(statistic=4.357217189667854, pvalue=1.3818150107521557e-05)
# AUC: 0.4933,0.6741,0.8469
# Ttest_indResult(statistic=-38.112981805833705, pvalue=3.678981307741121e-241)
# MAP: 0.004,0.0139,0.0324
# Ttest_indResult(statistic=-8.98497704770619, pvalue=5.689220032484439e-19)
# MRR: 0.009,0.0377,0.063
# Ttest_indResult(statistic=-9.247649977965812, pvalue=5.540702495889688e-20)
# Precision@5: 0.0025,0.0097,0.0162
# Ttest_indResult(statistic=-7.2795273236979, pvalue=4.737891241429691e-13)
# Precision@10: 0.0017,0.0084,0.0128
# Ttest_indResult(statistic=-9.057291314365356, pvalue=3.0144369007543546e-19)
# Precision@20: 0.0015,0.007,0.0102
# Ttest_indResult(statistic=-11.134517870646368, pvalue=5.246836662182017e-28)
# Precision@50: 0.0012,0.0055,0.0073
# Ttest_indResult(statistic=-14.092868122759528, pvalue=3.910996389213258e-43)
# Recall@5: 0.0049,0.0141,0.0348
# Ttest_indResult(statistic=-6.270758117603825, pvalue=4.362585000928994e-10)
# Recall@10: 0.0077,0.0232,0.0553
# Ttest_indResult(statistic=-7.87922340343382, pvalue=5.280982079825996e-15)
# Recall@20: 0.0124,0.0371,0.0864
# Ttest_indResult(statistic=-9.9954098581113, pvalue=5.266830544993525e-23)
# Recall@50: 0.0216,0.0723,0.1445
# Ttest_indResult(statistic=-13.36737847935802, pvalue=3.777308952501599e-39)
# NDCG@5: 0.0036,0.0139,0.0307
# Ttest_indResult(statistic=-6.907726926473927, pvalue=6.53352460943408e-12)
# NDCG@10: 0.0044,0.0169,0.0382
# Ttest_indResult(statistic=-8.24040881943281, pvalue=3.010849975828156e-16)
# NDCG@20: 0.0059,0.0217,0.0478
# Ttest_indResult(statistic=-9.861239211068838, pvalue=1.902002100884925e-22)
# NDCG@50: 0.0084,0.0317,0.0629
# Ttest_indResult(statistic=-12.299708855174979, pvalue=1.3211189114316142e-33)
# F1@5: 0.003,0.0098,0.0203
# Ttest_indResult(statistic=-7.207389847233927, pvalue=7.960885916160147e-13)
# F1@10: 0.0026,0.0109,0.0193
# Ttest_indResult(statistic=-9.255803881774943, pvalue=5.1492848896206834e-20)
# F1@20: 0.0025,0.0107,0.0172
# Ttest_indResult(statistic=-11.477015744167632, pvalue=1.3305447462492925e-29)
# F1@50: 0.0021,0.0097,0.0134
# Ttest_indResult(statistic=-14.433329061331849, pvalue=4.603348466496426e-45)
#
# > MF
# MAE: 1.2754,1.3005,1.3022
# Ttest_indResult(statistic=-0.6817457724858278, pvalue=0.4954761341316912)
# MSE: 2.7705,2.8582,2.9812
# Ttest_indResult(statistic=-1.135687463356277, pvalue=0.25621911595288804)
# RMSE: 1.3957,1.4647,1.4276
# Ttest_indResult(statistic=-0.7702038476524125, pvalue=0.4412670405028539)
# AUC: 0.508,0.5176,0.5278
# Ttest_indResult(statistic=-1.9845662634140704, pvalue=0.04732483822368564)
# MAP: 0.0019,0.0024,0.0026
# Ttest_indResult(statistic=-1.118989541900582, pvalue=0.2632746824909233)
# MRR: 0.0042,0.0072,0.0047
# Ttest_indResult(statistic=-0.3225061388015796, pvalue=0.74710192014076)
# Precision@5: 0.0004,0.0015,0.001
# Ttest_indResult(statistic=-1.163895644233494, pvalue=0.24460069754735977)
# Precision@10: 0.0007,0.0012,0.0007
# Ttest_indResult(statistic=-0.03992324623884139, pvalue=0.9681581754576862)
# Precision@20: 0.0008,0.0011,0.0008
# Ttest_indResult(statistic=-0.06073134506709967, pvalue=0.9515790419971899)
# Precision@50: 0.0005,0.0009,0.0006
# Ttest_indResult(statistic=-1.003536487982955, pvalue=0.31571960059586107)
# Recall@5: 0.0006,0.0015,0.002
# Ttest_indResult(statistic=-1.1023796367378238, pvalue=0.27042505916298004)
# Recall@10: 0.0024,0.0026,0.0033
# Ttest_indResult(statistic=-0.43640090446249324, pvalue=0.662591482286998)
# Recall@20: 0.0056,0.005,0.0078
# Ttest_indResult(statistic=-0.7468746273232771, pvalue=0.4552242282506237)
# Recall@50: 0.0091,0.0104,0.0132
# Ttest_indResult(statistic=-1.1523989657039508, pvalue=0.24929048942781204)
# NDCG@5: 0.0006,0.0017,0.0014
# Ttest_indResult(statistic=-0.9554340994590255, pvalue=0.3394699949999732)
# NDCG@10: 0.0013,0.002,0.0019
# Ttest_indResult(statistic=-0.5525740673759588, pvalue=0.580614879361805)
# NDCG@20: 0.0024,0.0029,0.0033
# Ttest_indResult(statistic=-0.770489023049627, pvalue=0.44109796011807445)
# NDCG@50: 0.0032,0.0045,0.0048
# Ttest_indResult(statistic=-1.2209116171101517, pvalue=0.22225880137409074)
# F1@5: 0.0004,0.0014,0.0011
# Ttest_indResult(statistic=-1.1385229654759408, pvalue=0.25503417607610446)
# F1@10: 0.0009,0.0015,0.001
# Ttest_indResult(statistic=-0.1570511074148306, pvalue=0.8752199157438034)
# F1@20: 0.0013,0.0017,0.0014
# Ttest_indResult(statistic=-0.2248716890970056, pvalue=0.8221013323377114)
# F1@50: 0.0009,0.0016,0.0012
# Ttest_indResult(statistic=-1.0610703340821384, pvalue=0.2887819599305887)
#
# > PMF
# MAE: 1.527,1.4242,1.4068
# Ttest_indResult(statistic=3.061631847452882, pvalue=0.0022297000921061285)
# MSE: 3.5658,3.2053,3.1052
# Ttest_indResult(statistic=2.769772759876513, pvalue=0.005659697999922611)
# RMSE: 1.6383,1.5817,1.5193
# Ttest_indResult(statistic=2.9512579269097046, pvalue=0.0032004621923417253)
# AUC: 0.5263,0.5975,0.6792
# Ttest_indResult(statistic=-15.122084932482755, pvalue=4.439656594490796e-49)
# MAP: 0.0033,0.0049,0.0076
# Ttest_indResult(statistic=-3.82145316160562, pvalue=0.0001365890571672341)
# MRR: 0.0069,0.0129,0.0127
# Ttest_indResult(statistic=-2.4637604700868674, pvalue=0.01382973064059031)
# Precision@5: 0.0013,0.0029,0.0031
# Ttest_indResult(statistic=-1.8592283052364715, pvalue=0.06313685963269873)
# Precision@10: 0.001,0.003,0.0034
# Ttest_indResult(statistic=-3.4751799726092574, pvalue=0.0005210443685235111)
# Precision@20: 0.0008,0.0027,0.003
# Ttest_indResult(statistic=-4.7019643792651715, pvalue=2.746899055387248e-06)
# Precision@50: 0.0009,0.0024,0.0025
# Ttest_indResult(statistic=-5.709386610545433, pvalue=1.2976859728043128e-08)
# Recall@5: 0.0027,0.0037,0.0074
# Ttest_indResult(statistic=-1.8952009865717356, pvalue=0.05820525341641023)
# Recall@10: 0.0043,0.0083,0.0155
# Ttest_indResult(statistic=-3.119951365702801, pvalue=0.0018337895848991909)
# Recall@20: 0.0065,0.0156,0.0292
# Ttest_indResult(statistic=-4.687032816838343, pvalue=2.9527515843381386e-06)
# Recall@50: 0.0148,0.0337,0.0577
# Ttest_indResult(statistic=-6.361109566983949, pvalue=2.459177748270728e-10)
# NDCG@5: 0.0023,0.0032,0.0043
# Ttest_indResult(statistic=-1.2918913435158526, pvalue=0.19653927037211052)
# NDCG@10: 0.0029,0.005,0.0075
# Ttest_indResult(statistic=-2.5045677217964837, pvalue=0.012336597360640713)
# NDCG@20: 0.0036,0.0074,0.0115
# Ttest_indResult(statistic=-3.8253879936124604, pvalue=0.0001344407934714708)
# NDCG@50: 0.0059,0.0124,0.0184
# Ttest_indResult(statistic=-5.365457553801535, pvalue=8.979010340469182e-08)
# F1@5: 0.0017,0.0028,0.0039
# Ttest_indResult(statistic=-1.7394425538994167, pvalue=0.08210587956845451)
# F1@10: 0.0015,0.0038,0.0052
# Ttest_indResult(statistic=-3.350696544035687, pvalue=0.0008205944072351957)
# F1@20: 0.0014,0.0042,0.0053
# Ttest_indResult(statistic=-4.754207819386182, pvalue=2.1297255750202007e-06)
# F1@50: 0.0016,0.0043,0.0047
# Ttest_indResult(statistic=-5.8631795240450515, pvalue=5.27356579109168e-09)
#
# > NMF
# MAE: 2.3132,2.1915,2.1741
# Ttest_indResult(statistic=2.9531269082202463, pvalue=0.0031812301360920636)
# MSE: 7.2147,6.5542,6.452
# Ttest_indResult(statistic=3.027146783592599, pvalue=0.0024992485917727926)
# RMSE: 2.4555,2.3605,2.3028
# Ttest_indResult(statistic=3.2132796002362194, pvalue=0.0013324959402367532)
# AUC: 0.5036,0.5279,0.5442
# Ttest_indResult(statistic=-4.230246390927269, pvalue=2.4363295008076412e-05)
# MAP: 0.0016,0.0016,0.0011
# Ttest_indResult(statistic=1.6342474589081741, pvalue=0.1023592547796414)
# MRR: 0.0029,0.0034,0.0016
# Ttest_indResult(statistic=2.164619601648446, pvalue=0.030531022619545427)
# Precision@5: 0.0002,0.0004,0.0
# Ttest_indResult(statistic=0.9894126505182883, pvalue=0.3225771475811172)
# Precision@10: 0.0005,0.0004,0.0001
# Ttest_indResult(statistic=1.6095919243863046, pvalue=0.10763974539689242)
# Precision@20: 0.0006,0.0004,0.0001
# Ttest_indResult(statistic=2.292844761833296, pvalue=0.021956995793887893)
# Precision@50: 0.0006,0.0004,0.0002
# Ttest_indResult(statistic=3.0097573801451634, pvalue=0.0026461988657208823)
# Recall@5: 0.0005,0.0005,0.0
# Ttest_indResult(statistic=0.9894126505182885, pvalue=0.32257714758111733)
# Recall@10: 0.0012,0.001,0.0005
# Ttest_indResult(statistic=0.9159181731250404, pvalue=0.3598167076142684)
# Recall@20: 0.0042,0.0017,0.0012
# Ttest_indResult(statistic=1.824569057917684, pvalue=0.06821044251626657)
# Recall@50: 0.0089,0.0044,0.0036
# Ttest_indResult(statistic=2.2777023489029187, pvalue=0.02284606726289685)
# NDCG@5: 0.0004,0.0005,0.0
# Ttest_indResult(statistic=0.9894126505182883, pvalue=0.3225771475811172)
# NDCG@10: 0.0008,0.0008,0.0002
# Ttest_indResult(statistic=1.2168489474134336, pvalue=0.22380067953628888)
# NDCG@20: 0.0017,0.001,0.0004
# Ttest_indResult(statistic=1.987356092224893, pvalue=0.04701478947738386)
# NDCG@50: 0.003,0.0018,0.001
# Ttest_indResult(statistic=2.6462425889026626, pvalue=0.008200904839580341)
# F1@5: 0.0003,0.0004,0.0
# Ttest_indResult(statistic=0.9894126505182884, pvalue=0.32257714758111733)
# F1@10: 0.0006,0.0006,0.0002
# Ttest_indResult(statistic=1.3830606441987994, pvalue=0.16679571864319473)
# F1@20: 0.0009,0.0006,0.0003
# Ttest_indResult(statistic=2.1893109646408706, pvalue=0.028685772305108163)
# F1@50: 0.001,0.0007,0.0004
# Ttest_indResult(statistic=2.99031123375905, pvalue=0.0028198614515834524)
#
# > WMF
# MAE: 6.127,5.6899,5.4596
# Ttest_indResult(statistic=9.131976656642546, pvalue=1.5567735895605775e-19)
# MSE: 41.5117,36.8245,33.864
# Ttest_indResult(statistic=9.542625200348779, pvalue=3.771648527586696e-21)
# RMSE: 6.237,5.8777,5.5893
# Ttest_indResult(statistic=9.097763850275653, pvalue=2.1083977309397733e-19)
# AUC: 0.6717,0.7137,0.8249
# Ttest_indResult(statistic=-16.47132948918182, pvalue=2.2753427693403046e-57)
# MAP: 0.0135,0.014,0.0296
# Ttest_indResult(statistic=-6.691043442079237, pvalue=2.8443801189203494e-11)
# MRR: 0.0215,0.0344,0.0468
# Ttest_indResult(statistic=-6.3894663499537, pvalue=2.0510790000231433e-10)
# Precision@5: 0.0065,0.0091,0.0166
# Ttest_indResult(statistic=-4.499229519437358, pvalue=7.198813486988605e-06)
# Precision@10: 0.0081,0.0101,0.0161
# Ttest_indResult(statistic=-4.689165483241948, pvalue=2.9224685462858995e-06)
# Precision@20: 0.0069,0.0085,0.0134
# Ttest_indResult(statistic=-5.675093481108876, pvalue=1.58151023596756e-08)
# Precision@50: 0.0045,0.0068,0.0093
# Ttest_indResult(statistic=-7.956979225170762, pvalue=2.878666883744394e-15)
# Recall@5: 0.0151,0.0131,0.038
# Ttest_indResult(statistic=-3.9025036582631265, pvalue=9.825167201976731e-05)
# Recall@10: 0.0394,0.0292,0.0756
# Ttest_indResult(statistic=-4.154778847881012, pvalue=3.3886898470259265e-05)
# Recall@20: 0.0622,0.0472,0.1236
# Ttest_indResult(statistic=-5.654903313059173, pvalue=1.775929458655913e-08)
# Recall@50: 0.0935,0.0891,0.2044
# Ttest_indResult(statistic=-8.610539456618582, pvalue=1.4170861061317867e-17)
# NDCG@5: 0.0088,0.0113,0.0235
# Ttest_indResult(statistic=-4.4319965168004, pvalue=9.825359112899155e-06)
# NDCG@10: 0.0177,0.0176,0.0377
# Ttest_indResult(statistic=-4.955943810905527, pvalue=7.783817780572465e-07)
# NDCG@20: 0.0249,0.0238,0.0522
# Ttest_indResult(statistic=-6.117068453605548, pvalue=1.1368645606222164e-09)
# NDCG@50: 0.0329,0.0359,0.0723
# Ttest_indResult(statistic=-8.33198211793666, pvalue=1.4296645830331777e-16)
# F1@5: 0.0082,0.0093,0.0211
# Ttest_indResult(statistic=-4.444049272879893, pvalue=9.295356753685424e-06)
# F1@10: 0.0126,0.0133,0.0248
# Ttest_indResult(statistic=-4.68646511455286, pvalue=2.960863372068055e-06)
# F1@20: 0.0117,0.0132,0.023
# Ttest_indResult(statistic=-5.855081842048045, pvalue=5.532641588956752e-09)
# F1@50: 0.0084,0.012,0.0173
# Ttest_indResult(statistic=-8.231225927313602, pvalue=3.242990524810834e-16)
#
# > PF
# MAE: 6.8119,6.715,6.7388
# Ttest_indResult(statistic=1.0967204956312744, pvalue=0.27289140879475804)
# MSE: 49.6862,48.3579,48.621
# Ttest_indResult(statistic=1.2790433719519503, pvalue=0.20102542273061477)
# RMSE: 6.8864,6.8159,6.8182
# Ttest_indResult(statistic=1.0451580991461207, pvalue=0.2960721730649417)
# AUC: 0.5407,0.6532,0.7835
# Ttest_indResult(statistic=-25.18928043811918, pvalue=2.5465409060933604e-122)
# MAP: 0.0045,0.011,0.0253
# Ttest_indResult(statistic=-7.531682863198614, pvalue=7.441582003294322e-14)
# MRR: 0.0084,0.0283,0.0442
# Ttest_indResult(statistic=-8.302557174960308, pvalue=1.817702981920331e-16)
# Precision@5: 0.0017,0.0079,0.0147
# Ttest_indResult(statistic=-6.606909806227745, pvalue=4.977362808764293e-11)
# Precision@10: 0.0017,0.0075,0.013
# Ttest_indResult(statistic=-8.654057260490042, pvalue=9.814569368080845e-18)
# Precision@20: 0.002,0.0064,0.0105
# Ttest_indResult(statistic=-9.59128933243226, pvalue=2.403508334017066e-21)
# Precision@50: 0.0019,0.0046,0.0065
# Ttest_indResult(statistic=-9.071024351446344, pvalue=2.6705197207102883e-19)
# Recall@5: 0.0037,0.0117,0.0307
# Ttest_indResult(statistic=-5.877750210600961, pvalue=4.83682611361173e-09)
# Recall@10: 0.0063,0.0219,0.0528
# Ttest_indResult(statistic=-7.879874371837655, pvalue=5.25434132931986e-15)
# Recall@20: 0.0137,0.0371,0.0855
# Ttest_indResult(statistic=-9.424071110908274, pvalue=1.1207883534352608e-20)
# Recall@50: 0.034,0.0646,0.1286
# Ttest_indResult(statistic=-9.890932178813307, pvalue=1.433422329271081e-22)
# NDCG@5: 0.0024,0.0105,0.0233
# Ttest_indResult(statistic=-6.190046821672128, pvalue=7.233880467449456e-10)
# NDCG@10: 0.0035,0.0141,0.032
# Ttest_indResult(statistic=-7.831626154653091, pvalue=7.635942117669321e-15)
# NDCG@20: 0.006,0.0192,0.0421
# Ttest_indResult(statistic=-9.25823584461815, pvalue=5.037929816174028e-20)
# NDCG@50: 0.0112,0.027,0.0532
# Ttest_indResult(statistic=-10.087442816854564, pvalue=2.1634957907613638e-23)
# F1@5: 0.0021,0.0082,0.0182
# Ttest_indResult(statistic=-6.538719153492655, pvalue=7.796337671628832e-11)
# F1@10: 0.0024,0.0099,0.0192
# Ttest_indResult(statistic=-8.836448733832084, pvalue=2.0671122663225133e-18)
# F1@20: 0.0032,0.01,0.0177
# Ttest_indResult(statistic=-9.963442182514239, pvalue=7.161875136137696e-23)
# F1@50: 0.0035,0.0082,0.0121
# Ttest_indResult(statistic=-9.417547806646386, pvalue=1.1895856074201517e-20)
#
# User groups evaluation is started ...
# > MostPop
# ERROR! Session/line number was not unique in database. History logging moved to new session 47
# MAE: 2.783,2.492,2.2878
# Ttest_indResult(statistic=7.435886545867454, pvalue=1.5136696550071922e-13)
# MSE: 11.7564,9.8648,8.5401
# Ttest_indResult(statistic=7.2084482543848045, pvalue=7.90077178584305e-13)
# RMSE: 3.0491,2.7949,2.4931
# Ttest_indResult(statistic=8.16753585321936, pvalue=5.417120323531059e-16)
# AUC: 0.4565,0.6504,0.8367
# Ttest_indResult(statistic=-38.68671438668353, pvalue=9.523758201539388e-247)
# MAP: 0.0039,0.0137,0.0322
# Ttest_indResult(statistic=-8.944187413421709, pvalue=8.12395520430788e-19)
# MRR: 0.0088,0.0377,0.0632
# Ttest_indResult(statistic=-9.316096299920646, pvalue=2.9901590689904625e-20)
# Precision@5: 0.0021,0.0096,0.0176
# Ttest_indResult(statistic=-7.812383257669373, pvalue=8.858433085942772e-15)
# Precision@10: 0.0017,0.0084,0.0128
# Ttest_indResult(statistic=-9.057291314365356, pvalue=3.0144369007543546e-19)
# Precision@20: 0.0015,0.0071,0.0101
# Ttest_indResult(statistic=-10.999975511097023, pvalue=2.1640913669642567e-27)
# Precision@50: 0.0012,0.0055,0.0073
# Ttest_indResult(statistic=-14.261750488110026, pvalue=4.3650432953913717e-44)
# Recall@5: 0.005,0.013,0.0373
# Ttest_indResult(statistic=-6.484883139605801, pvalue=1.107758598583287e-10)
# Recall@10: 0.0077,0.0232,0.0553
# Ttest_indResult(statistic=-7.87922340343382, pvalue=5.280982079825996e-15)
# Recall@20: 0.0128,0.0381,0.0857
# Ttest_indResult(statistic=-9.876504340749628, pvalue=1.644757031553074e-22)
# Recall@50: 0.0225,0.0733,0.1453
# Ttest_indResult(statistic=-13.297750809217671, pvalue=8.92212728516134e-39)
# NDCG@5: 0.0034,0.0136,0.032
# Ttest_indResult(statistic=-7.1676902398073, pvalue=1.0571005659479935e-12)
# NDCG@10: 0.0043,0.0169,0.0382
# Ttest_indResult(statistic=-8.255445689960375, pvalue=2.6656235413147095e-16)
# NDCG@20: 0.006,0.0219,0.0477
# Ttest_indResult(statistic=-9.79652891049462, pvalue=3.513751887242722e-22)
# NDCG@50: 0.0085,0.0319,0.0631
# Ttest_indResult(statistic=-12.326601979197116, pvalue=9.684797271946846e-34)
# F1@5: 0.0026,0.0094,0.0218
# Ttest_indResult(statistic=-7.71672664067964, pvalue=1.844204951724181e-14)
# F1@10: 0.0026,0.0109,0.0193
# Ttest_indResult(statistic=-9.255803881774943, pvalue=5.1492848896206834e-20)
# F1@20: 0.0025,0.0109,0.0172
# Ttest_indResult(statistic=-11.307000329179973, pvalue=8.345716243709952e-29)
# F1@50: 0.0021,0.0097,0.0135
# Ttest_indResult(statistic=-14.589027179952312, pvalue=5.867069787413548e-46)
#
# > BPR
# MAE: 6.7712,6.5882,6.4793
# Ttest_indResult(statistic=4.355839815426434, pvalue=1.3904539020886894e-05)
# MSE: 49.1674,46.7407,45.217
# Ttest_indResult(statistic=4.818509748253695, pvalue=1.5515973129193404e-06)
# RMSE: 6.8474,6.6915,6.5615
# Ttest_indResult(statistic=4.357217189667854, pvalue=1.3818150107521557e-05)
# AUC: 0.4933,0.6741,0.8469
# Ttest_indResult(statistic=-38.112981805833705, pvalue=3.678981307741121e-241)
# MAP: 0.004,0.0139,0.0324
# Ttest_indResult(statistic=-8.98497704770619, pvalue=5.689220032484439e-19)
# MRR: 0.009,0.0377,0.063
# Ttest_indResult(statistic=-9.247649977965812, pvalue=5.540702495889688e-20)
# Precision@5: 0.0025,0.0097,0.0162
# Ttest_indResult(statistic=-7.2795273236979, pvalue=4.737891241429691e-13)
# Precision@10: 0.0017,0.0084,0.0128
# Ttest_indResult(statistic=-9.057291314365356, pvalue=3.0144369007543546e-19)
# Precision@20: 0.0015,0.007,0.0102
# Ttest_indResult(statistic=-11.134517870646368, pvalue=5.246836662182017e-28)
# Precision@50: 0.0012,0.0055,0.0073
# Ttest_indResult(statistic=-14.092868122759528, pvalue=3.910996389213258e-43)
# Recall@5: 0.0049,0.0141,0.0348
# Ttest_indResult(statistic=-6.270758117603825, pvalue=4.362585000928994e-10)
# Recall@10: 0.0077,0.0232,0.0553
# Ttest_indResult(statistic=-7.87922340343382, pvalue=5.280982079825996e-15)
# Recall@20: 0.0124,0.0371,0.0864
# Ttest_indResult(statistic=-9.9954098581113, pvalue=5.266830544993525e-23)
# Recall@50: 0.0216,0.0723,0.1445
# Ttest_indResult(statistic=-13.36737847935802, pvalue=3.777308952501599e-39)
# NDCG@5: 0.0036,0.0139,0.0307
# Ttest_indResult(statistic=-6.907726926473927, pvalue=6.53352460943408e-12)
# NDCG@10: 0.0044,0.0169,0.0382
# Ttest_indResult(statistic=-8.24040881943281, pvalue=3.010849975828156e-16)
# NDCG@20: 0.0059,0.0217,0.0478
# Ttest_indResult(statistic=-9.861239211068838, pvalue=1.902002100884925e-22)
# NDCG@50: 0.0084,0.0317,0.0629
# Ttest_indResult(statistic=-12.299708855174979, pvalue=1.3211189114316142e-33)
# F1@5: 0.003,0.0098,0.0203
# Ttest_indResult(statistic=-7.207389847233927, pvalue=7.960885916160147e-13)
# F1@10: 0.0026,0.0109,0.0193
# Ttest_indResult(statistic=-9.255803881774943, pvalue=5.1492848896206834e-20)
# F1@20: 0.0025,0.0107,0.0172
# Ttest_indResult(statistic=-11.477015744167632, pvalue=1.3305447462492925e-29)
# F1@50: 0.0021,0.0097,0.0134
# Ttest_indResult(statistic=-14.433329061331849, pvalue=4.603348466496426e-45)
#
# > MF
# MAE: 1.2754,1.3005,1.3022
# Ttest_indResult(statistic=-0.6817457724858278, pvalue=0.4954761341316912)
# MSE: 2.7705,2.8582,2.9812
# Ttest_indResult(statistic=-1.135687463356277, pvalue=0.25621911595288804)
# RMSE: 1.3957,1.4647,1.4276
# Ttest_indResult(statistic=-0.7702038476524125, pvalue=0.4412670405028539)
# AUC: 0.508,0.5176,0.5278
# Ttest_indResult(statistic=-1.9845662634140704, pvalue=0.04732483822368564)
# MAP: 0.0019,0.0024,0.0026
# Ttest_indResult(statistic=-1.118989541900582, pvalue=0.2632746824909233)
# MRR: 0.0042,0.0072,0.0047
# Ttest_indResult(statistic=-0.3225061388015796, pvalue=0.74710192014076)
# Precision@5: 0.0004,0.0015,0.001
# Ttest_indResult(statistic=-1.163895644233494, pvalue=0.24460069754735977)
# Precision@10: 0.0007,0.0012,0.0007
# Ttest_indResult(statistic=-0.03992324623884139, pvalue=0.9681581754576862)
# Precision@20: 0.0008,0.0011,0.0008
# Ttest_indResult(statistic=-0.06073134506709967, pvalue=0.9515790419971899)
# Precision@50: 0.0005,0.0009,0.0006
# Ttest_indResult(statistic=-1.003536487982955, pvalue=0.31571960059586107)
# Recall@5: 0.0006,0.0015,0.002
# Ttest_indResult(statistic=-1.1023796367378238, pvalue=0.27042505916298004)
# Recall@10: 0.0024,0.0026,0.0033
# Ttest_indResult(statistic=-0.43640090446249324, pvalue=0.662591482286998)
# Recall@20: 0.0056,0.005,0.0078
# Ttest_indResult(statistic=-0.7468746273232771, pvalue=0.4552242282506237)
# Recall@50: 0.0091,0.0104,0.0132
# Ttest_indResult(statistic=-1.1523989657039508, pvalue=0.24929048942781204)
# NDCG@5: 0.0006,0.0017,0.0014
# Ttest_indResult(statistic=-0.9554340994590255, pvalue=0.3394699949999732)
# NDCG@10: 0.0013,0.002,0.0019
# Ttest_indResult(statistic=-0.5525740673759588, pvalue=0.580614879361805)
# NDCG@20: 0.0024,0.0029,0.0033
# Ttest_indResult(statistic=-0.770489023049627, pvalue=0.44109796011807445)
# NDCG@50: 0.0032,0.0045,0.0048
# Ttest_indResult(statistic=-1.2209116171101517, pvalue=0.22225880137409074)
# F1@5: 0.0004,0.0014,0.0011
# Ttest_indResult(statistic=-1.1385229654759408, pvalue=0.25503417607610446)
# F1@10: 0.0009,0.0015,0.001
# Ttest_indResult(statistic=-0.1570511074148306, pvalue=0.8752199157438034)
# F1@20: 0.0013,0.0017,0.0014
# Ttest_indResult(statistic=-0.2248716890970056, pvalue=0.8221013323377114)
# F1@50: 0.0009,0.0016,0.0012
# Ttest_indResult(statistic=-1.0610703340821384, pvalue=0.2887819599305887)
#
# > PMF
# MAE: 1.527,1.4242,1.4068
# Ttest_indResult(statistic=3.061631847452882, pvalue=0.0022297000921061285)
# MSE: 3.5658,3.2053,3.1052
# Ttest_indResult(statistic=2.769772759876513, pvalue=0.005659697999922611)
# RMSE: 1.6383,1.5817,1.5193
# Ttest_indResult(statistic=2.9512579269097046, pvalue=0.0032004621923417253)
# AUC: 0.5263,0.5975,0.6792
# Ttest_indResult(statistic=-15.122084932482755, pvalue=4.439656594490796e-49)
# MAP: 0.0033,0.0049,0.0076
# Ttest_indResult(statistic=-3.82145316160562, pvalue=0.0001365890571672341)
# MRR: 0.0069,0.0129,0.0127
# Ttest_indResult(statistic=-2.4637604700868674, pvalue=0.01382973064059031)
# Precision@5: 0.0013,0.0029,0.0031
# Ttest_indResult(statistic=-1.8592283052364715, pvalue=0.06313685963269873)
# Precision@10: 0.001,0.003,0.0034
# Ttest_indResult(statistic=-3.4751799726092574, pvalue=0.0005210443685235111)
# Precision@20: 0.0008,0.0027,0.003
# Ttest_indResult(statistic=-4.7019643792651715, pvalue=2.746899055387248e-06)
# Precision@50: 0.0009,0.0024,0.0025
# Ttest_indResult(statistic=-5.709386610545433, pvalue=1.2976859728043128e-08)
# Recall@5: 0.0027,0.0037,0.0074
# Ttest_indResult(statistic=-1.8952009865717356, pvalue=0.05820525341641023)
# Recall@10: 0.0043,0.0083,0.0155
# Ttest_indResult(statistic=-3.119951365702801, pvalue=0.0018337895848991909)
# Recall@20: 0.0065,0.0156,0.0292
# Ttest_indResult(statistic=-4.687032816838343, pvalue=2.9527515843381386e-06)
# Recall@50: 0.0148,0.0337,0.0577
# Ttest_indResult(statistic=-6.361109566983949, pvalue=2.459177748270728e-10)
# NDCG@5: 0.0023,0.0032,0.0043
# Ttest_indResult(statistic=-1.2918913435158526, pvalue=0.19653927037211052)
# NDCG@10: 0.0029,0.005,0.0075
# Ttest_indResult(statistic=-2.5045677217964837, pvalue=0.012336597360640713)
# NDCG@20: 0.0036,0.0074,0.0115
# Ttest_indResult(statistic=-3.8253879936124604, pvalue=0.0001344407934714708)
# NDCG@50: 0.0059,0.0124,0.0184
# Ttest_indResult(statistic=-5.365457553801535, pvalue=8.979010340469182e-08)
# F1@5: 0.0017,0.0028,0.0039
# Ttest_indResult(statistic=-1.7394425538994167, pvalue=0.08210587956845451)
# F1@10: 0.0015,0.0038,0.0052
# Ttest_indResult(statistic=-3.350696544035687, pvalue=0.0008205944072351957)
# F1@20: 0.0014,0.0042,0.0053
# Ttest_indResult(statistic=-4.754207819386182, pvalue=2.1297255750202007e-06)
# F1@50: 0.0016,0.0043,0.0047
# Ttest_indResult(statistic=-5.8631795240450515, pvalue=5.27356579109168e-09)
#
# > NMF
# MAE: 2.3132,2.1915,2.1741
# Ttest_indResult(statistic=2.9531269082202463, pvalue=0.0031812301360920636)
# MSE: 7.2147,6.5542,6.452
# Ttest_indResult(statistic=3.027146783592599, pvalue=0.0024992485917727926)
# RMSE: 2.4555,2.3605,2.3028
# Ttest_indResult(statistic=3.2132796002362194, pvalue=0.0013324959402367532)
# AUC: 0.5036,0.5279,0.5442
# Ttest_indResult(statistic=-4.230246390927269, pvalue=2.4363295008076412e-05)
# MAP: 0.0016,0.0016,0.0011
# Ttest_indResult(statistic=1.6342474589081741, pvalue=0.1023592547796414)
# MRR: 0.0029,0.0034,0.0016
# Ttest_indResult(statistic=2.164619601648446, pvalue=0.030531022619545427)
# Precision@5: 0.0002,0.0004,0.0
# Ttest_indResult(statistic=0.9894126505182883, pvalue=0.3225771475811172)
# Precision@10: 0.0005,0.0004,0.0001
# Ttest_indResult(statistic=1.6095919243863046, pvalue=0.10763974539689242)
# Precision@20: 0.0006,0.0004,0.0001
# Ttest_indResult(statistic=2.292844761833296, pvalue=0.021956995793887893)
# Precision@50: 0.0006,0.0004,0.0002
# Ttest_indResult(statistic=3.0097573801451634, pvalue=0.0026461988657208823)
# Recall@5: 0.0005,0.0005,0.0
# Ttest_indResult(statistic=0.9894126505182885, pvalue=0.32257714758111733)
# Recall@10: 0.0012,0.001,0.0005
# Ttest_indResult(statistic=0.9159181731250404, pvalue=0.3598167076142684)
# Recall@20: 0.0042,0.0017,0.0012
# Ttest_indResult(statistic=1.824569057917684, pvalue=0.06821044251626657)
# Recall@50: 0.0089,0.0044,0.0036
# Ttest_indResult(statistic=2.2777023489029187, pvalue=0.02284606726289685)
# NDCG@5: 0.0004,0.0005,0.0
# Ttest_indResult(statistic=0.9894126505182883, pvalue=0.3225771475811172)
# NDCG@10: 0.0008,0.0008,0.0002
# Ttest_indResult(statistic=1.2168489474134336, pvalue=0.22380067953628888)
# NDCG@20: 0.0017,0.001,0.0004
# Ttest_indResult(statistic=1.987356092224893, pvalue=0.04701478947738386)
# NDCG@50: 0.003,0.0018,0.001
# Ttest_indResult(statistic=2.6462425889026626, pvalue=0.008200904839580341)
# F1@5: 0.0003,0.0004,0.0
# Ttest_indResult(statistic=0.9894126505182884, pvalue=0.32257714758111733)
# F1@10: 0.0006,0.0006,0.0002
# Ttest_indResult(statistic=1.3830606441987994, pvalue=0.16679571864319473)
# F1@20: 0.0009,0.0006,0.0003
# Ttest_indResult(statistic=2.1893109646408706, pvalue=0.028685772305108163)
# F1@50: 0.001,0.0007,0.0004
# Ttest_indResult(statistic=2.99031123375905, pvalue=0.0028198614515834524)
#
# > WMF
# MAE: 6.127,5.6899,5.4596
# Ttest_indResult(statistic=9.131976656642546, pvalue=1.5567735895605775e-19)
# MSE: 41.5117,36.8245,33.864
# Ttest_indResult(statistic=9.542625200348779, pvalue=3.771648527586696e-21)
# RMSE: 6.237,5.8777,5.5893
# Ttest_indResult(statistic=9.097763850275653, pvalue=2.1083977309397733e-19)
# AUC: 0.6717,0.7137,0.8249
# Ttest_indResult(statistic=-16.47132948918182, pvalue=2.2753427693403046e-57)
# MAP: 0.0135,0.014,0.0296
# Ttest_indResult(statistic=-6.691043442079237, pvalue=2.8443801189203494e-11)
# MRR: 0.0215,0.0344,0.0468
# Ttest_indResult(statistic=-6.3894663499537, pvalue=2.0510790000231433e-10)
# Precision@5: 0.0065,0.0091,0.0166
# Ttest_indResult(statistic=-4.499229519437358, pvalue=7.198813486988605e-06)
# Precision@10: 0.0081,0.0101,0.0161
# Ttest_indResult(statistic=-4.689165483241948, pvalue=2.9224685462858995e-06)
# Precision@20: 0.0069,0.0085,0.0134
# Ttest_indResult(statistic=-5.675093481108876, pvalue=1.58151023596756e-08)
# Precision@50: 0.0045,0.0068,0.0093
# Ttest_indResult(statistic=-7.956979225170762, pvalue=2.878666883744394e-15)
# Recall@5: 0.0151,0.0131,0.038
# Ttest_indResult(statistic=-3.9025036582631265, pvalue=9.825167201976731e-05)
# Recall@10: 0.0394,0.0292,0.0756
# Ttest_indResult(statistic=-4.154778847881012, pvalue=3.3886898470259265e-05)
# Recall@20: 0.0622,0.0472,0.1236
# Ttest_indResult(statistic=-5.654903313059173, pvalue=1.775929458655913e-08)
# Recall@50: 0.0935,0.0891,0.2044
# Ttest_indResult(statistic=-8.610539456618582, pvalue=1.4170861061317867e-17)
# NDCG@5: 0.0088,0.0113,0.0235
# Ttest_indResult(statistic=-4.4319965168004, pvalue=9.825359112899155e-06)
# NDCG@10: 0.0177,0.0176,0.0377
# Ttest_indResult(statistic=-4.955943810905527, pvalue=7.783817780572465e-07)
# NDCG@20: 0.0249,0.0238,0.0522
# Ttest_indResult(statistic=-6.117068453605548, pvalue=1.1368645606222164e-09)
# NDCG@50: 0.0329,0.0359,0.0723
# Ttest_indResult(statistic=-8.33198211793666, pvalue=1.4296645830331777e-16)
# F1@5: 0.0082,0.0093,0.0211
# Ttest_indResult(statistic=-4.444049272879893, pvalue=9.295356753685424e-06)
# F1@10: 0.0126,0.0133,0.0248
# Ttest_indResult(statistic=-4.68646511455286, pvalue=2.960863372068055e-06)
# F1@20: 0.0117,0.0132,0.023
# Ttest_indResult(statistic=-5.855081842048045, pvalue=5.532641588956752e-09)
# F1@50: 0.0084,0.012,0.0173
# Ttest_indResult(statistic=-8.231225927313602, pvalue=3.242990524810834e-16)
#
# > PF
# MAE: 6.8119,6.715,6.7388
# Ttest_indResult(statistic=1.0967204956312744, pvalue=0.27289140879475804)
# MSE: 49.6862,48.3579,48.621
# Ttest_indResult(statistic=1.2790433719519503, pvalue=0.20102542273061477)
# RMSE: 6.8864,6.8159,6.8182
# Ttest_indResult(statistic=1.0451580991461207, pvalue=0.2960721730649417)
# AUC: 0.5407,0.6532,0.7835
# Ttest_indResult(statistic=-25.18928043811918, pvalue=2.5465409060933604e-122)
# MAP: 0.0045,0.011,0.0253
# Ttest_indResult(statistic=-7.531682863198614, pvalue=7.441582003294322e-14)
# MRR: 0.0084,0.0283,0.0442
# Ttest_indResult(statistic=-8.302557174960308, pvalue=1.817702981920331e-16)
# Precision@5: 0.0017,0.0079,0.0147
# Ttest_indResult(statistic=-6.606909806227745, pvalue=4.977362808764293e-11)
# Precision@10: 0.0017,0.0075,0.013
# Ttest_indResult(statistic=-8.654057260490042, pvalue=9.814569368080845e-18)
# Precision@20: 0.002,0.0064,0.0105
# Ttest_indResult(statistic=-9.59128933243226, pvalue=2.403508334017066e-21)
# Precision@50: 0.0019,0.0046,0.0065
# Ttest_indResult(statistic=-9.071024351446344, pvalue=2.6705197207102883e-19)
# Recall@5: 0.0037,0.0117,0.0307
# Ttest_indResult(statistic=-5.877750210600961, pvalue=4.83682611361173e-09)
# Recall@10: 0.0063,0.0219,0.0528
# Ttest_indResult(statistic=-7.879874371837655, pvalue=5.25434132931986e-15)
# Recall@20: 0.0137,0.0371,0.0855
# Ttest_indResult(statistic=-9.424071110908274, pvalue=1.1207883534352608e-20)
# Recall@50: 0.034,0.0646,0.1286
# Ttest_indResult(statistic=-9.890932178813307, pvalue=1.433422329271081e-22)
# NDCG@5: 0.0024,0.0105,0.0233
# Ttest_indResult(statistic=-6.190046821672128, pvalue=7.233880467449456e-10)
# NDCG@10: 0.0035,0.0141,0.032
# Ttest_indResult(statistic=-7.831626154653091, pvalue=7.635942117669321e-15)
# NDCG@20: 0.006,0.0192,0.0421
# Ttest_indResult(statistic=-9.25823584461815, pvalue=5.037929816174028e-20)
# NDCG@50: 0.0112,0.027,0.0532
# Ttest_indResult(statistic=-10.087442816854564, pvalue=2.1634957907613638e-23)
# F1@5: 0.0021,0.0082,0.0182
# Ttest_indResult(statistic=-6.538719153492655, pvalue=7.796337671628832e-11)
# F1@10: 0.0024,0.0099,0.0192
# Ttest_indResult(statistic=-8.836448733832084, pvalue=2.0671122663225133e-18)
# F1@20: 0.0032,0.01,0.0177
# Ttest_indResult(statistic=-9.963442182514239, pvalue=7.161875136137696e-23)
# F1@50: 0.0035,0.0082,0.0121
# Ttest_indResult(statistic=-9.417547806646386, pvalue=1.1895856074201517e-20)

# %%
sns.set(rc = {'figure.figsize':(6,2)})

for metric in ['MAE', 'Precision@10', 'Recall@10', 'NDCG@10']:
  data = [[], [], []]
  labels = [['', '', '', '', '', '', '', '', ''], [], []]

  for item in metric_group_results[metric]:
    # print(item)
    data[0].append(item[0])
    data[1].append(item[1])
    data[2].append(item[2])


  for item in ttest_group_results[metric]:
    if item[0] < 0.005:
      labels[1].append('*')
    else:
      labels[1].append('')
    if item[1] < 0.005 and item[2] < 0.005:
      labels[2].append('**')
    else:
      labels[2].append('')

  fig, ax = plt.subplots()
  ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
  ax.set_xticklabels(['MostPop', 'BPR', 'MF', 'PFM', 'NMF', 'WMF', 'PF', 'NeuMF', 'VAECF'])
  ax.set_yticklabels(['Niche', 'Diverse', 'BestSeller'])
  ax.tick_params(axis='x', rotation=280)
  ax.tick_params(axis='y', rotation=0)
  plt.savefig(f'{metric}_metric_analysis.pdf', dpi=300, bbox_inches='tight')
# Out:
# H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py:174: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   annot_data = np.asarray(annot)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\2118517087.py", line 25, in <module>
#     ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 448, in heatmap
#     yticklabels, mask)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 177, in __init__
#     raise ValueError(err)
# ValueError: `data` and `annot` must have same shape.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\2118517087.py", line 25, in <module>
#     ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 448, in heatmap
#     yticklabels, mask)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 177, in __init__
#     raise ValueError(err)
# ValueError: `data` and `annot` must have same shape.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\2118517087.py", line 25, in <module>
#     ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 448, in heatmap
#     yticklabels, mask)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 177, in __init__
#     raise ValueError(err)
# ValueError: `data` and `annot` must have same shape.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py:174: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   annot_data = np.asarray(annot)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\852884410.py", line 25, in <module>
#     ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 448, in heatmap
#     yticklabels, mask)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 177, in __init__
#     raise ValueError(err)
# ValueError: `data` and `annot` must have same shape.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\852884410.py", line 25, in <module>
#     ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 448, in heatmap
#     yticklabels, mask)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 177, in __init__
#     raise ValueError(err)
# ValueError: `data` and `annot` must have same shape.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "H:\TEMP\ipykernel_8288\852884410.py", line 25, in <module>
#     ax = sns.heatmap(data, annot=labels, fmt = '', cmap="Blues")
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 448, in heatmap
#     yticklabels, mask)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\seaborn\matrix.py", line 177, in __init__
#     raise ValueError(err)
# ValueError: `data` and `annot` must have same shape.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "H:\Anaconda\envs\tf15\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "H:\Anaconda\envs\tf15\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "H:\Anaconda\envs\tf15\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "H:\Anaconda\envs\tf15\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
